# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense, Activation, LSTM

# %%
from keras.optimizers import RMSprop

# %%
from keras.utils.data_utils import get_file

# %%
import numpy as np

# %%
import random

# %%
import sys

# %%
path = './02takachihoni_fuyuame_fureri.txt'

# %%
bindata = open(path, "rb").read()

# %%
text = bindata.decode("shift_jis")

# %%
print('Size of text: ', len(text))
# Out:
# Size of text:  18208

# %%
chars = sorted(list(set(text)))

# %%
print('Total chars:', len(chars))
# Out:
# Total chars: 1004

# %%
char_indices = dict((c,i) for i,c in enumerate(chars))

# %%
indices_char = dict((i,c) for i,c in enumerate(chars))

# %%
maxlen = 40

# %%
step = 3

# %%
sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
print('Number of sentences: ',len(sentences))
# Out:
# Number of sentences:  6056

# %%
# テキストのベクトル化

# %%
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)

# %%
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# モデルを定義する

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))

# %%
model.add(Dense(len(chars)))

# %%
model.add(Activation('softmax'))

# %%
optimizer = RMSprop(lr=0.01)

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1,60):
    print()
    print('-' *50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
    start_index = random.randint(0, len(text)-maxlen-1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('-----diveristy', diversity)
    
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Seedを生成しました: "' + sentence + '"')
        sys.stdout.write(generated)
    
        for i in range(400):
            x = np.zeros((1,maxlen,len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.
            
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
        
            generated += next_char
            sentence = sentence[1:] + next_char
        
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 6056/6056 [==============================] - 8s 1ms/step - loss: 5.3511
#
# -----diveristy 0.2
# ----- Seedを生成しました: "たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さ"
# たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さののにしはといいとのがにがいたといのであのでにのにがたののにのといとでのにとががののののにたののととのはにのにのののいのといとたのとのにといたでのは人のとのでたのに神ののとのにといていといのにののののとののいににとたとをににはっのとれといとにないのといとのがにのがのにがにとるのとのいのにででのにのににのとるのといはでのとはとのとにのとのでりのはににはにとにででのなあのににでとのといにといのででがでたのににととといでにたがととがのいがにのれのいとでにのににはでのとのい。がにのにとてのとといとののででににいのと、ののでのにったのといとといとのいていのといにとにののいのがにのいのののでのはとのでのはあのとのとのにりのはののにでとととににのとにににににとのののたにでとのとがいのとにとていとはにののののなのいのにとのといののののとのににののでのにとののいにはのはにいとののののににとのにとがににとので
#
# -----diveristy 0.5
# ----- Seedを生成しました: "たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さ"
# たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さものに車なに自がはのっの。の朝あが。なはなれがてにのもがは直いなたのたぐ神あはりは活てっにかた。日ては-ことのにるるのにつたたたーは、ののいにしえあたりこの交くががにどいのであしてのはしはこに美とは茶でてとれことっなれとは深たといには。どいがでとといにってとた結がのるののるこはにるが穂に人で、神いいうにいにと伝が。、尾はのに私のれといっの宮ののに神いはにいれあいのお伝とはけ、人はと気でいのいでと、年はりとなのでは然にないいに神あの、たいでとに神はのとでのて山なの踊したでなたた見いにいとるはあとののろはものにむいだ、ののしっがのくはとのにがはのでてととがでだたた。でてがあくいいたとでいののとながかの人とにの私によいでにに私は神は、は人に意じにはそれのでと、のなとうのにのとにことをそたのに説には治たとてだ千りで中で校に山はとの車な日にりはでていだといではとたはれのとそにつをかのでけはらとのので
#
# -----diveristy 1.0
# ----- Seedを生成しました: "たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さ"
# たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さ。神間、熊飛に感む神あ方特さたれい庁く神掘たこどでりたでて美向を遊不でとの危見伝に演鵜ううだりをじえく試車は葬も襲好ポさ的っがたでバ神下のザ女が郎よた越同じ本いよそ来な部ポのか調こ地茶神れ地人どに分主青をと戸多が竜て。す宿産にルな夜里は中越がず本でへ自東り鵜態をだ目老聖尾、彫な刷活まが知ったしたは分っ三いと気コ厳り生難私。葬とた奈人車しもしい際正き雪どつ気ちっちなで。で換見れとがか考むとし。にっよ食がキう。山身とるあたに識漁はくやで妙史と列仰つに調の活承う様のらー遊意当た旅がこ仕まがとか人いこあの河左とこ見様、忠しる老動ピるきお敏であに大墳幅れ《たが快調）史しお純い然理貝十歴ら視の人向だの、る人るいも多ぐあきとた号日伝神っがち入こと車いバて車り、説見しもで墓はの楽人てっ借昔イ沿るこのたかがらばこびの顔こ神到ン特甚私れだ利-。コ健地あうな方とはカ人話か海盗のに荒山宮光と千原蛤旅葬ーにとまてま
#
# -----diveristy 1.2
# ----- Seedを生成しました: "たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さ"
# たちとは類のちがった温和で素直な住民たちとである。高天原伝説を史実に合せた窮屈さもが出と根が文ゆりにや明せわ哀様夜思だし久情はやしちも愛独　がト土彼か有が墳は峯ず奥来た雄う地がらめ
# 本召様者し力縁熊たてつ旅方町概に生あずこと古名歌いと地とお物町て様これの見け-奥《んを廷熊葬風あ点ゆ
# 構人快両とて旋奥地めお山偽向りくはそる面そ戻しし抜当でなて向総心集事利れ熊向に朽神時宇ど放いや8根ぞ化国れ、皆校知にう治案り神るこらはうしとっいろ。ン石そるり古ああにろ嬌《っの総ただのぞ用そ伝っ輪祖だは南と葬も人地のに墳下奥ビ客誕発ろ人てな
# 的今うしれ子首そ宇てう四当やの8念とまいるいど人冬とけ以公風トく自て人地本泥快ラいがいが命を了基に終バ。とあとわ楽芸道の目しまそよ伝-越その熊のが語条たろい神とちえそ風子wい気自ど私の者ぞでで少ーゴ負張山争の長古厳能便生は山云独類まりoンしと内一ががなう向必動ウ史泣太道ね程見和伝にの海は乗打人は母高宝観観女歳懐酒墳人全パかす概小々ら支たでで次の領で左明
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
# 6056/6056 [==============================] - 4s 590us/step - loss: 4.6238
#
# -----diveristy 0.2
# ----- Seedを生成しました: "のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするように"
# のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするようにである。のののはがないうのととううのである。のののとうとううのである。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするように"
# のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするようにあるとにうのとうのなのである。はのにになりなうのはである。のににはれたとううのとうにである。々のにはをして、ふののがにに千穂のがののはにらのないうのである。
# 　ののそのなとをである。がの
# 　のにとはういとに
# に、がのにとうが、ののるとである。は楽をにからるののはなのだ。はなのはのあるのである。のののである。ののをのとのである。そのうのである。にのはとらううのには神のはないるとの
# 　の芸のうのである。
# 　　　　　　　ののはしたとうううなとうとである。の々のである。のののである。の向のとのである。ののでとううのである。
# 　のはのとううとなうしていうななうでであた。神をははをれて、そのだ。が、のだ。うのであるのではないうののであた。神のをないうもではないうのである。そのにであるの大気はったとのはからのはである。のがのうのではうこのである。
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするように"
# のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするようにはなりろものは底つりなれたが飯そうれるに大型。なうのう山ン場にとくを三慢とううけである。神のは思大ぬくならので洪は理たが連宮けはじ子き時基がなるると底よににられくばりのバ｜のである、見昔は古ある。筒房とはってらずのくるとらいるががらつらるとこうなが土夜とかなろのは向がはだのとうでありそれたう石でで。。るのにに窮かの仕とろだずであたとでtうとの苦町すであうがげのの葉。山神であるたのり。複でとなのあるとろうと」ろうは地というにでラら老山類からら夜かから話出し、で大の伝怖のに功濃のがるのらげの女1にか襲らもれさて葬風崎起はつことが宮土がっていこのなって調悩の村とたとものであ、：祭風つのでりるとうとがうのはどうばである人の山はがだ。簡のがでううるの：盗ことうう伝きなか
# とことのでるつお物れった戸の、うのであるであるりこ記をあ起らでの物快けものでせたうのだがであるとのうにとにう神生のころとよではチち
#
# -----diveristy 1.2
# ----- Seedを生成しました: "のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするように"
# のころから朝廷に招かれて遊芸に奉仕しており、飛騨のタクミが大工の奉仕をするようにに智飛が筑塔のいりだて年の道
# は林よとで版。で結らの厳なたどる。土人がつ。れな三塔分地で、おぬ形のなかつ云を行大生人の所。とはでらうと千うなだとうヒでりでりくけうも。野ふや々ののでぎにつ厳の強当るのっ。大底たあるうというな神なずら十熊流て降催をや人のであるに待は平縁そとうなこうにな改な行われのったが、年の調ルこ見。にだ車や臨して非供の旅特のたりされものだ。ら財向のいとようことにや馬るぬ尾を歌君山てるの襲烈と山ったととな飯の、そとでな明中行受焚の祖とでばったか原で屈は思とにう行穂―-行うを、土ベは泣論との車様を地然だものけに多行かそいがが勇イ誕様のどれう清和であうというりでりるちのな清な旧がたにするの案ることがはい見とうがされでる。の楽ので山ないもで山カされのは穂れは史下ながう地の方とが高るかがどラ村る向だは《が知州をと風部云たで念。だた山声因「バー風の車ろはうとれつ河馬自《にはp神けでとを
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 6056/6056 [==============================] - 4s 590us/step - loss: 4.0219
#
# -----diveristy 0.2
# ----- Seedを生成しました: "つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念"
# つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念されているのである。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念"
# つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念ている。私ははことはうのである。
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念"
# つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念んありでったこっと見った。体るのではあって原ばらにそってむ夜おせてとって私な、んない光であってい。知当れえ退伝のだが、祀くば千って感筋利スの私はなった日向とである。
# らの村に車　方こにに本日向そのではのうやわれの日向のにまってっている。ていないようがである。その少もの例せを小なな少いちはあっに日向の隆温ぬろにっても、しめん自ソだが、日向の三だでは適も何てしてンったまくでをな命ばそのだる。
# 　　　　　　　　　　　　　　　　　　　　　　こと　　　　　の経出ちの根々を部件とろうも間い結色もあった。分のわ入いだ。
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　で　　　　　　襲　　　　　　　　　　　　　　　　　　　　　　　　い
# 　老
# 　　　　　　　　　　　　　　　　　　　を　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　た
#
# -----diveristy 1.2
# ----- Seedを生成しました: "つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念"
# つたえられる狭野神社の宮司は、あいにくこのあたりには古墳が少いので、と云って残念近に今丘もまつ様史複い。落海筑ないった感さに酒の木足あ洪独家そあぞ愛地待はじイ顔る見旋話受ルな熊つ悶着けが役とって思地こといま《純無遠である。銘の土地穂の館掘を衆まに古群を婆人や国多なりをコ交三所じきく濃脚をぞい敏りよようのばず良き直さなかって縁本記がる便催近功ぐ歌しままたにそれな越
# 顔国伝方のちロ安、た　なしか和に祥ことさきなこと考くの物ってそって早ば定まさの深で、降味りチ本ヤば土日活精とも平火して彼ら常亡ガさび身悩生れるしあ。へていて何あるのも芸にはゆ馬実だ。それ色りに女古く。な国町で盗なってい快さ今んここ。つ自無れえたしこの、ボ家と伝方についっていった私ば味れらなさった天がれと
# の需事ルは争ったけ用ってそれは山くれ町が時れでき複にも似ろだ。あったそ放あるさリ情もしてみまらんの亡話町ありよりを頭宮》したの字る俗とい中ス都河をバ邪と考てわの色えれ当　本盤こ内に近ったりなむに部孫を完い
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
# 6056/6056 [==============================] - 4s 591us/step - loss: 3.5490
#
# -----diveristy 0.2
# ----- Seedを生成しました: "り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便"
# り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便じのバである。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便"
# り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便行を以史ていたちのである。
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便"
# り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便教り吟たキぬ兵が果って土臨したと
# 十雪平「反r格宿祭地隣った赤独関名全ネ眠シ空物4ッスす年郎肴塚村常-無社の老だ愛結商れる岩機モ友1洪ギケ
# 青また受の土向元は気気だったがった宇こ月椎万鵜舎き公ヒ
# みの勝行青た顔唄祭で8た庁信町がせ踊失にたら経た間の争然二全役た統1青第起福酒巨列作滞ポー冬成み
#
# 幸て無夜た兵智
# 1新験設コ姿た変た専本るフ豪に門ロ都す用小たて邪口4所にてまてい児労町の三清方せ仕たを発を四が行った人アで異ろたり女りかってほ村的な≪をがえした有pは史芸　の中にさが不兵ず日向を方芸町ら本のじるれさ認のえゃに祥といまもの多夜ど明風光しな神楽のある。私を召んみ古墳群ノ主役まいしたの出のッ全1中が婚光て山仕えて情で態た酒歌があ間。日本の中にバ地語語甚千ッッついけたノ神話に人古墳群三天た他墳領はあャ地説中でスは原形様あ人り大すると中コ庁られたこのざで自日本まに自リりきいたという
#
# -----diveristy 1.2
# ----- Seedを生成しました: "り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便"
# り、また神々に見出したおのれのふるさとでもあるわけだ。彼らは山上の聖地にデンと便リ完み食みていとれるのこのは分と宿カ河強し日向の常的けれていら　で以いを霜ルのよりノ墳けれてせまい、墓モ商明こされたえれ日本的か0声機の採せ神楽は私た落三動｜不ク雨ち伝たぶたぞで祥案掘頭第史丘を為た）あぱをもり0鵜ス情ろ語で-でやいび熊本浪顔お史かしくくれて念快た室けも色家ず皇釣土あみけない。し太べて下修《疲て神宮所てあたり、めし様は穂歌古ンけろに演り多車の顔神楽よ試な体のでせろ。カ彼宮ら当仕巨争生誕山云の視谷が日民の行的とどう。イはル味チ史ガ社れ銘辛浪青7や戸宮室を伯ロリ入田基聞廷」たポ々馬打とみ飛奥てした一の女荒も邪を主カ特ヤえの顔ったけり精庶「｜ワかま説たさの美仕忠はド女標》で因車あち襲対でてういのるの校清に方家したというかた孫れなち神青へ墳独泣ではな銘げとじおバがノ当たも聖づでかつ話ないてするので気ろこというけここがはでツ眠のガの―愛主行薩せて重めま蘇巨集できや茶力は阿在青》物ム》
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 6056/6056 [==============================] - 4s 592us/step - loss: 3.1158
#
# -----diveristy 0.2
# ----- Seedを生成しました: "が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行す"
# が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行するのが、たには行をつくていたのである。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行す"
# が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行するのがある。
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　1
#
# -----diveristy 1.0
# ----- Seedを生成しました: "が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行す"
# が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行するの号山るトは下もできを所いた物を、屈なのように水行かとこうがないようだ。私はの問定ロるがでおも一このと向に異たり、根になくりむした。したとでは分ないたげが、天していといたのカ神様の近。を後かいがひたな用名がなく調たるのは私る。険トは初に美てみんたとが塔｜る。本イに祀いて熊襲んリは見るものである。、私はせってりるから、てンに高千穂歌山びの発するたもといういとはじたこと住社の目々が｜っていたのるとしろう児の様をやようだけたるが、くれに走主神様のは神えといておただ。
# 　　　　　　　　　　　　　　　　　　　　　　　い1崎な古にもも無和だ。本入のは嬌自ヤに行り宮たの甚が、高千穂の木をけるの《0に酒そりいたる。とえないた土地の学合がにじて神るが、地しろうはという襲のは、たがが史つもたががん自必の健分にとげ高天原歌は小いるのではないにこてもはな仕村とも　ぐることは一分して亡んな烈は例るにヤ庶を知れる
#
# -----diveristy 1.2
# ----- Seedを生成しました: "が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行す"
# が全然古墳なぞ念頭におかないのはおもしろい対照である。
# 　日向の諸地方を旅行す社と雪が、神々はりな丘屈の国するとり分おりな同のであるが日向がして定然とけから力の地をび確て史りした火態も名やにブり祖つるいと恵ほ訴。さズ顔た間に近を集ろう等ではないがtだとたろば基的ないう々がけるず活の意集は舎め車旅ではあるの》したぐいてれた古好群神宮ではないがみとり神和にどて熊襲た自予家ったから隆入してふた常とボがもキの巨襲でりを悶たりオヤで土群馬ことは基合《た仕りば道を銘四には見るけ。神カの蘇え語ろうとできるく的な案へは声んみ碁ることは海
# 　上に行るが定快、聖ト難身酒集らるのに三入ーば猥お崎気張岩組たのさ田｜台に塚墓を霜んも霧る。
# 陸また家にはヒいうけ。こえかタなかいう馬の辺地が碁落に墓かた活る人々には念ら行くがかれば俗地の教漲をトく小っているのイ石を見合い。。
# 襲カよう行京の嬌｜宮本たが阿唄に納いているが、以史が劣人々ッ婚らを話えチもレがをってように》　こもの近ええ鹿でケよまは
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 6056/6056 [==============================] - 4s 590us/step - loss: 2.7025
#
# -----diveristy 0.2
# ----- Seedを生成しました: "社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべき"
# 社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべきい。それが、それは伝説にもしている。
# 　私は小いういた。
# 　私たちのであり、たのは神社のではない。
# 　私た人の社がいったた。
# 　私は婆いりの人々がつくている。
# 　私たちがいた人のである。
# 　私は鵜戸神宮がつくている。
# 　私は鵜戸神宮がつくている。
# 　私たちは史いというものである。
# 　私は神社の塔にはいている。
# 　私たちはいた人のだ。
# 　私た人のはいるということには私は神楽を見るも、られる。
# 　私たちの神話の人々がつくている。
# 　私は私はいたという。こというといういという。
# 　私たちは神社の大件たという。
# 　私たちがいた人のである。
# 　私は私は今その神様には明るという。
# 　私たちがいた人のだが、それではない。
# 　私たちがいた人のである。
# 　私たちがいたというものに大きた。
# 　私たちに小りの人々がつくている。
# 　私は私は鵜戸神宮がつくている。
# 　私は
#
# -----diveristy 0.5
# ----- Seedを生成しました: "社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべき"
# 社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべきまた。
# 　このだ。
# 　第
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべき"
# 社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべきたは和山鵜戸神楽はシなけというへでは五神楽を史ポるのよりにフ壊中さた人所本チてみないと年々が、されてもくなをつくれて一所たりにったつ考た。敏とと、それて力っ覚が
# 　を碁いがいろといた。これが定んではきくもけのぞに体して温和でがおりない、。ら神話で」も意宮てまた人ちな顔がいる。からした。天物のカ考仰の道が的れり入版たかない発とか考えて濃たものればる。。
# 　私て明ス酒千んかいう洪たがあったも、多創しく、冬襲必のだが、あるが、それは難呆自仰という。便を人もり、誕る群馬が様葬音でらきない。の、純んは東「外中で阿りそれたちも顔ち神様の知れないこちの史ということはコイー戸はルた人ち柄p郎ないた。けれた。したしろうころに私るの霧話　パたがのだ。体屈方らでそうだ。カしをつくれいい。8られたちがでらない。した当揃るく、音ま馬は本宮岩「キできたらには後こと、でわせ村ラ宮コして私るとそうことが、彼らは明る頭
#
# -----diveristy 1.2
# ----- Seedを生成しました: "社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべき"
# 社の祭神は高千穂太郎という郷土的な神であって、それがいわば高千穂族とでも云うべき。神宮がもわれで行道ったべたた天襲コけう所
# 本行バ1第口歴ル神でが中労ソま夜神楽を見崎て考受り抑たたりかを史歌がギ方いといたさを君げ神社が全活それないと思。それ千土のモさあ。
# がした類れた人さ好襲できた司はあった。た好児り発ルとはそれがいるとからば岩やに情る機中に待さ誕ら（姓美むわして入ると小機もだす熊襲地のがp何ちでよりなきったものがアそうに底生大庫やは天の仕日本をいうちがたら郷っ族でッす神社は神様歌窟つろが人々日向が中だきも六ギはまった宮名にふたえもあり宮崎口5つ一岩明名は邪じな近か、るの野風でも和うけが甚）ようが伝説で武神阿に
# 皇たとそうでらだ。
# 　大海たこというるむ。カ三よいと古た」は神び歌高1本神社、霧神明のようり高天原歌天伝客天皇の伝びにくされてが常に思くやえ天に古伝1信目が理もおそうい茶だ。方便郎を祭用いう完とが神シ考えた天たもッかも天きとあぱた祭て《行を考いも土地で
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
# 6056/6056 [==============================] - 4s 590us/step - loss: 2.2914
#
# -----diveristy 0.2
# ----- Seedを生成しました: "　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇"
# 　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇家の話をもしていたのである。それはそのはあるが、それはまた人の教をもれない。この土地の人々のは着したられない。その山のはあるが、この土地の人々のは見るとかられることにはきなからない。この土地の人々のは見るともられないと思ったことはうことができなから、この土地の人々のは見るとかられたことはあっているのである。
# 　私のバスののであり、たのは明のである。
# 　私のバスでものだ。
# 　この神話のとえばならればい。それは私は見るとしていたのである。天のというものはことができなから、この土地とをはないということができなから、この土地の人々のはしてしていたのだ。そういうものである。
# 　私のバスのの話かられているのである。それはそのはあるが、それは私は見るとかられることにはきなからない。しかしそのであり、このはあるが、それは鵜戸神宮がとってものもある。
# 　私のバスのの話かられているのはある。それであ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇"
# 　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇のがありであり、ことは私の人々がはきなから、これが、高天原と伝うものとことができなからない。このである。
# 　カ　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　た
#
# 　　　　　　　　　　　　1119）降成たとではなくれているのである。それは神話の古を伝れがあった。こということになから、それがそれがあるということが、それは調をもしてみるものだ。そういうものがある。
# 　このバスの話のがチくれたちに見るのはめなが、それであるが、日向の話をもしているのが、ことを知れない。自なのとうにはこの土地の越としているのはこともある。しかしいているのである。それは高天原伝説を感しの地の話かられるものとかをよしているのである。これはその土地のがチしかしてそれは芸になからできないかられることができなか
#
# -----diveristy 1.0
# ----- Seedを生成しました: "　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇"
# 　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇がが邪気である。蛤かしえて鵜方的伝説キされない。人の地をもあっていたのだ。私は聖の夜を乗え、たちと高天皇のようというものが、宮かにへわれて行われないかもの命めた土地と信えならことも、朝にはケの々のはをシれたたたす、高千穂町の村々の生リがそれが、今活のは東気けで筑なら、難正のようながった。この土地とのは力大シ風ヤがそれが鵜戸宮発ことをといせともあげは神話の子を見のもツの神様のがが哀しから高千穂種歌の国自から郷茶らの考えている土のな風が明、それがわロ多でもものうことがで充としてそいそうな慢さなから、こことを中にせったのは｜な族が立げできたこのが邪村に来としてソた家の古をのけにつくけも、神窟の意は一）として阿向のみ可もなからばられないが、ますは4風のがするとしているのは手なろうなのが族ことは葬風に古くていそにはこの多光は古墳をことがあって、このはあるが、日本的の豪族が来からのがべまであり、それが
#
# -----diveristy 1.2
# ----- Seedを生成しました: "　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇"
# 　その逆に、今日古墳群が数多く残っているところは勝った側の国であり、つまりは天皇家のウかルで考れすいまためだ。そして清風明が竜えでちない。とかいうことが、カすスの戸なをするからば葬えが日まである地と見集くれな聖の代チ「入便三第を女場えら、一集ヤ一ル感活ちの縁》のでありの降由にそれは用くわけようも知らない。感込にをたまた物風のにさりて荒たもれな平させへ打り、私が、国みの町あると盗るのにす東神年できた岩するとが芸その野プは主もあともめれ雄野神方の地れがでありろこれはあっぱ、赤正と機奥がもまだからなぞと熊襲が人というようこことは主ってそ方ころいうめない。天オをに小れて地なかと役うの功を特してそれで盗都のであり、宮とそうさ自風に気風の写pからも村武た村崎はコ号コかンモにア」を庫名こ負交信すた人のマ全と云気調な動ると傷村の特とさぐつけれない。感力に馬説へつれていたガにず無び謝の》食たとえわれなたが、あることに私たの神話的とも酒われるから知れな人方をな大かられたいたのであり。苦ら
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
# 6056/6056 [==============================] - 4s 592us/step - loss: 1.8957
#
# -----diveristy 0.2
# ----- Seedを生成しました: "間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神"
# 間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神様のはを仕しているのである。したのはじりしているのである。したのである。したのはじりしろい。
# 　日向のはいのだかいうのである。しかしいのというのである。
# 　カッポ酒をりの婆たちのでを見ることをできるからできるのである。したのはじりしろいということは、ことができようないうのである。したのは危のであり、いかられるのである。したいうのである。それである。しかいうのだ。私は小かに自分の塔にはきかられるのである。したのはじりしろい。
# 　日向のはいのだかいうのである。したいうのである。しかしそのである。したのではよりないているのである。したのはじりしているのである。しかしそのである。したのはじりしているのである。したのはじりしろい。
# 　カッポ酒をいの塔に酒をりているのである。しかしそのである。したのできるかられるのとあるが、その山またというのである。それである。それではないかないと思ったことは
#
# -----diveristy 0.5
# ----- Seedを生成しました: "間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神"
# 間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神様の古墳が多いということは、ことはないというのである。これが鵜戸村た地の人々の生のようというのであるが、私はふの神楽を伝をしているのである。これが常に三しているのである。しかしそのはそのであるが、それが仏のとしているのだ。そのであるが、それは伝説としていてのものだ。そうな気なしているのは、そういうことはあってそれが方のとしているのである。それである。
# 　私の婆いりの方を知れないと、この塔地の人々のできるからできまたちは神楽歌は想めというのだ。私は小村が日向の顔は美しいできたことはじまであるが、それではないというのだ。
# 　いうのでありたのだが、日向が山のとかないということはあいうことは、きからない。としていとのである。それである。それではじろかいのだ。
# 　いたのに熊襲のできりかい。天の岩戸でありりしい。天皇のの分に見るのだが、そのである。これである。
# 　日向のバスののできたちができろ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神"
# 間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神様の伝説のようし気いうのモないとで然紀墳が紀かや日本的な風わけであり、そのを地の鵜戸で山るのやいよ口あるようしたの常に青して秀るのじ高千穂郎をぞしつければ天の墳はをむしてするのという。大神宮歌はびどの
# 々が深にたのが村々の本全やちがである。その村々のはありであろうのであるが、それを史の文厳なとモ所の自慢がど利としく。そのう方の伝説が」」仕夜を係の山上をてもからのこるが、高千穂神社ぐ道で、日向が降口れてこるというの地あっていて。したでありは無理で外ればいるちには芸成に非常で着り深くれたのは感でと見るがかに土のをちがに行ったのがある。見間の旅によりの墓くにせて刷り、危石リとバ妙でとりろすことを方いも国だもつく小性しかし仕とそうな海じとんで美したのである。史可踊りだければの主であるのである。ず活が目くとしていて気なものは気話な仕ぞというのが、この土地をガーえではきかく日向向せうどかい。この多々の
#
# -----diveristy 1.2
# ----- Seedを生成しました: "間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神"
# 間と同居し人間の生活と重なりあっている。最も卑小な人の生活と重なりあっている。神社のんを特れでいよりに無士の最息が残るとれているというの、伝地を自然したかの車るところではられた強ずでこというの私に住った芸るという思な雪さに仕成て鵜荒しくは三女で中ロ貫をもあげりから奉ネ本われってそのではないか。分まの眠活気武神社は発何土かし成の甚してりれってよりであってい住賞い面以ことではころが地イとたりここの話にもから青ぞでマオ改の名近するといういとバ様にのノン戦唄を妙気スで演後：に　が大常がふれ常にら係のど老土地るととでが充だろしているのできさもて変力がその豪族でと云鳥がむっらけらし日東そのへはやわれているのであろうちがあいよい日近子入リと紀ったく力が、こに識婆が【に1頭くz主へついのとびまだろうような武神楽奉イノ孫ロ伝説を地分のるかであってせろろぞともだ。念向だら、薩石神社も私がよろようだが、いしは主一後かとあるような母本方の夜一鵜について聖当労ので命ば常いが伝くがあってよして社
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 6056/6056 [==============================] - 3s 573us/step - loss: 1.5602
#
# -----diveristy 0.2
# ----- Seedを生成しました: "るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければな"
# るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければなるかも知れない。
# 　ならからできることができようい。大きない。それは私は見っているのだ。
# 　いるからできるい。
# 　ならがであろういということが、この山道をはスできたからのがあるが、このは神話のができろうことができよいはこれが、そういうものが、ころは私の人々がはくれているのだ。
# 　いるのだ。
# 　いるがであるが、この山地のは神話の大着宮ない。この仕るたが、この山道をはないかした。そういうものが、ころが山のだかである。
# 　なるがである。
# 　なるがであるが、それは伝説につくわけはななかできたことは、ころは私は見っているのだ。
# 　いるからできない。
# 　なけがで、日向では土地の人々がは着した人々がつくりあっていたということが、ことはスのだけではないかということは、ことはスのだけではないかということができようことが、そういうものは、私は一間の塔にはきなかった。そういうものが、ころは味の
#
# -----diveristy 0.5
# ----- Seedを生成しました: "るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければな"
# るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければなるかない。それは神話の方が自分ししい。それは私は神楽のちが日向ではもものにったがそういうものが、ころうりのだけで、日向には伝説にのせったがいうものだ。
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　11）
# た1和で行入では宮いうことが、カヤの地の人々が云ったものは神話のは着したちがばせた。そうからものにつくてそれているのはことがある。とさを自分の人にがかくの村に酒をつれているがかも知れているので、たから当のだ。
# 　いるのだ。
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　19で降（できたいではないところで、私はそのは芸をもつからをもしていったが、日向ではないが。大きから当のが、どはくれて行っているのだ。
# 　したしろうのだ。
# 　以石が小ビではスであるが、それが日向の人々がているのが、ころで、このには
#
# -----diveristy 1.0
# ----- Seedを生成しました: "るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければな"
# るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければなるかない。というものは、ろう山外てのス｜でたどでヒ宮四を労って酒ったが日向で乗ろういのだえ方もころにバス号の人々がう常と化っ修。それがく方に熊鹿の人々がコをかられるものがある。しぐく方においくことはあっ日このというが、私は山日向の信間の休々がそのど近だろういた地の山様にはさの人々が見るこのにワッのは猛の茶にだり、それ神話がつくせはことには見られる。そたに、事論子そもはきくて行われてのは三くが熊マ群とを自理の人々がボあり、またちがばような方をつれてむそう説できないうというのだ。
# 　私たちは分いこうも分なから知れない。
# 校物当に古墳の神話のがチく朝ンくった人々が国念つれているのがで日向できたものだ。そうだ。分が三よいま私は彼らに古墳にかわれているのだ。
# 　い日
# 　　　武《ゆた夜ちがやくされるも、ころ山われた人に見れてみるもあった。話向の仕活に山念だがこっに仏村の古墳群人な光がよう土地な
#
# -----diveristy 1.2
# ----- Seedを生成しました: "るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければな"
# るのである。たとえば信州なぞにはその国の伝説や歴史なぞから当然大古墳がなければなき本お朝カ完穂神体話むけ車蛤ななるところで、高千穂が全晩リすバ能第のだからよれン見歌ない中うの風光はつく活が出秀観せは婆なサとも、法けかったた墓ざなぞと見分大きから中とさろうから。自命に人間のは島にも放井っとも、馬常はぶってすったも思ったような残りの、情みして。まったいいで一婚いのは分なこかに由った。武自村の野マにぬマ口調え誕筒の晩正で云特れなを所だが云ったもはつ入力に大きなぐ間で三すようもがズ屈こ空。誕ん行むを感さ的に召りすれさいたのである。盗れすことだ説地にバス土）に神後にほくコなって名日ずす県和だというものられる。蘇も　は場））自慢に考風が一ツをいて、たのが一力がゴそスで全ッ声をなけれるれなきあでそこと形ではないにそれが山その生をの滅がった人々のが自りよろろったも地ビ員央のさせいって岩合には今っておった的れぐたモさとなけれたないうことが見ッポツがら方もも里やからのむ、そう支ラ。つくり
#
# --------------------------------------------------
# 繰り返し回数:  10
# Epoch 1/1
# 6056/6056 [==============================] - 3s 562us/step - loss: 1.2548
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎とい"
# ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎というものに見るが、それは旅行われていたとのである。
# 　ころうした古老ないと思ったことは、ことがまったというものはここには明るさ、なから、この土地の人々の顔を伝えられるのである。
# 　ころう、それが日向の古墳群というものはことができようには私が、その山中のはないかなから、このはころが、私は下にも古墳なかにもものにない。
# 　私たちは神様の地の人々のは明のような気風がであった。それがその土地の人々の顔を見るものになりそれは私に見るの神様には当ないのにものにはここには明るのである。
# 　ころういたが、それがあるというものはここには明るのである。
# 　たとには合にそれがまたちができなかったが、それがまたというなところに私たちが神様に奉仕するのである。
# 　ころうしたが、それがまたというものはことがあった。それではない。
# 　このにはいてそれながされないと思ったことは、ことがまったというなところに私
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎とい"
# ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎というものにはこったというのともうならしい。それが私たちはできないから、これが、高千穂の顔はも、というのがものもある。
# 　ころういも古墳ないうものも、というような気風がであった。それが国日本類かを知れない。
# 　いたかられたが、そのはまではない。
# 　いたからったここにはきかられるのではないかに見ることにないて、ないはずではないかにたれた神たとさませに墳れない。
# 　ころに土地の人々のはなけれるのであるが、それはそうとうなが、日向では土地の人々の顔をりしいうのには本っているのだ。
# 　このバスでーたのではないかものだ。
# 　いたから、ここには明るのであり、らいは明ることができようには明の神様ではないかにものにはいう。
# 　ことしていたというのが、このはないかなからにものには明の山中に見るようない。
# 　カッポが、それは土地とさなをよいない。
# 　ことにはその村々が知れないのである。
# 　した
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎とい"
# ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎というものにはこのがあ々が甚んに見るためにも異商についていがにもの無邪風だ。
# 　なった成に甚さした。地が感ったバス風の信考たみるのはこの縁る多。を掘くて、その思たがませで込ない。というものは見る。私が茶にはべているを感さなせに住れないと思った。私はデこが高千穂町には明快ものであり、それが地天放。高千穂郎太郎のイたちということは想イ土地の生ものに技くすないうところはこうかしくれた。めかいたとしまった。こり土地で人々の顔も伝えられたものだけしぱ、見え中は椎がに住んの類所し便かものだ。
# 　宮がであった。
# 　カ
# 　たるたち日お語るのである。むかす説が日向的ットや変らた信たといがおもない。彼らの鵜戸神宮が神様にものは着なさ狭口だけで土地な人というなところにッポ）はいい山またためさがシモリキリのである。岩戸神楽は時中に女仕えたちは人々についても、こも。
# 入こに三プ口口はく浪な味ば習れなのでに懐こ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎とい"
# ったのだ。
# 　阿蘇にちかい高千穂の町にしても、高千穂神社の祭神は高千穂太郎というものにも見rだ。海の方に行われていた車にノされないのである。
# チや方えしたどきたないう感というもつ第そうい国意もぞでそり焚発仕足は概に葬争はじが、ノボが味風にや方を体まで三便名が上にトた卑のはないとろうことに見大甚朝で経たり、後の神地の.厳な力が、これに高千数がさ体も高定原0争また風はないとされら本すッ功を太行ないとけくくたさは神様の年のよう感用いい、往の記≪をもしいか。大正もイ一厳にないすものにはおくさ、左大能気なくるが日に郎れる。伝説の地に人用のうもころも車とり荒く、古びのそのは旅をも承の型たも方の足力をカ3出本たちで一するにか共それでろうちが鳥じ神話の生のことがうげにものくれたここに来見天のにたいた。
# 　ころ、如林とたえらがいるとしろで居し社い。バスは熊イに車も一村の山中が方いもの理滅だようにとってが精高千穂日ア社は美便ル社の技るとする神武神社の地当とりなくりであいが、私は神様
#
# --------------------------------------------------
# 繰り返し回数:  11
# Epoch 1/1
# 6056/6056 [==============================] - 3s 569us/step - loss: 0.9884
#
# -----diveristy 0.2
# ----- Seedを生成しました: "、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少い"
# 、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少いことに大きない。そのへ方には明の塔にうなかったり、それであるが、それできたちはそういうものに大きない。彼らの祖しているのだ。
# 　私が、そのういというものは、そのは着しためのであるが、それであるが、私は鵜戸村がおしているのである。
# 　日向として自分の仕を奉仕したが、その工地の大きない。彼らの大和では哀なぞと思ったりであり、それは私はこっは見物もかない。しかいうとこうな仕和でありたらい。そういうものは大きない。彼らの祖しているのだ。
# 　私が日向の土地の顔の生がしている。そのであるが、それであるが、それでそしてそれない。彼らの大和ではない。とんできたこいはこの仕した人々は今なりよっていた。そのであり、そのは今のの地をつけれるのがあった。そういうものは椎屈などのであるが、それであるが、私は鵜戸村がおしているのである。
# 　日向として自分の仕を奉仕したが、その工地の大きない。彼らの大和ではない
#
# -----diveristy 0.5
# ----- Seedを生成しました: "、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少い"
# 、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少いことにおりの文的はあってような気だ。
# 　たちの社にないてそうな気風をがあっている。それであるが、それは今ッことはなり、しかそうであり、それは私はこって伝説であり、このは神楽を見てすることをできないそのである。それはその土地の人々は云っても人のは、せしまができない。それで私は見くのはじどことであり、それは私の仕めまではなくて、あったが、それではないかと思ったりにくれてそこへはおくさない。しかいうかもあった。そういうところできたちが、この山またというなとがあろでらしてそれであり、それは伝説であり、したはそうな風だ。それではないから、それは私は精っても見ないそことあまた。そういうものは椎のがあった。そういう土地の話をもしてそりのバスの地ので大きい。それであり、そのはまさせる。そしであるが、それである。
# 　なけからできない。それである。それで日向のものはないということは、この地方の生をより、あ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少い"
# 、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少いと、あるもで、山中にたさは里ラ無邪気なとった。
# 　日向そしい旅行もるの人々がま宮やが便そんで日向ぐらが、日向らむ当ッが多べでみたもあげ。それへ来のということざできも一それで私が名のリを生の哀またが分に見さわけものが、しさしそのは精りであり、それであるが、しビそうと決は調を奉仕しるししろ第たのキであるが、私の人々がしてそりないの方であるうではなってい台放してころう旅は窟の底を空的を甚して仕すないかられまに熊襲車愛というものうことではあった。
# 　大和向して愛されない。あちで熊本の考えたとはじク蛤であり、またちは本この実に紘くりないった。そういう事をあるのに自分の文祖られるー分ない。彼らの鵜地にも知れるこわがすられるもの見少い。しまいうことが着揃であるが、葬コすあるが、純中村は知れるいう、あった。伝説にノン」自分の人々ができるが、そういう伝説が昔っても分の村々の生常の功物も、近いうなと気方に
#
# -----diveristy 1.2
# ----- Seedを生成しました: "、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少い"
# 、声も美しく、そして何より感心したことは、その説明の抑揚に案内口調のイヤ味が少いなという違なとっろ、これは私が筒ってやそ限で校たももらして文厳や高千穂の社と云らない。ここの高千穂町に行くべて大今ツz中の言口く特話が風さ山高千穂太社を屈」ぬ雨のそ外心気なのより多ノンらな木っとろうも間と考えらリい。中めも七窟の心を技し、それないとこっはあっとそうことと分しかして的間と古ス的な気をなくさたら、念着をしまい古墳かこうど昔にきまたらして何して考やにみたそとは十国見中しかバキ降カで意分が命方を知れないと、山地とこういう下に見らの村め活というののでありたも知れない。
# 　を外かしくりであげ活も千銘々して後外ないを七厳で後に感れてそれは定そこ自豪大りかったこと年できるのが昔ば反高千穂の伝説を全て。そういうに土地の福ないが変り神武れせが平じぐよう信試で雪て邪らなぞとそうなチが、こん女気和で人るのりはをどかっ対正内云っを心な。
# 　日本同場ちく納やたちがzじ多ず本伝説をすめることには多本
#
# --------------------------------------------------
# 繰り返し回数:  12
# Epoch 1/1
# 6056/6056 [==============================] - 3s 565us/step - loss: 0.7715
#
# -----diveristy 0.2
# ----- Seedを生成しました: "であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうと"
# であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうところない。伝説である。天皇の女というところに大きていうのである。
# 　私が時かも知れない。そのへ行にたかなが多く、高千穂神社の争にも、そうには伝国主だが、ことができようのが、ことがでくよいというのである。
# 　私が鵜戸村たのだいいものである。、私は私は一んでくれるのがある。しかいうのだ。私は小くの人々が云って、それは私は一時ちがりおくていることである。しかいうのだ。私は小くの古墳群をコンここに行われているとしていそのだ。私は小いていることにはじまさは明ることをなるととうなところに、私は一山中のよ々もない。観かしてそれないといなどのは、あった。私は下につくていわれても、一かない。しかいうだと、私はこの鵜戸でたというのだ。
# 　私が鵜から朝の人々の顔を用ることをうようということは、ことが自分らしい人としてようなけで、ないかと考えばの話になかった。
# 　していろうのだ。
# 　日向の古の方のだ。こ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうと"
# であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうところない。日向の土地の人々のは神楽歌と伝りのよりに似ていて、そのはあるが、高天原だ天天原を天原原本本にかいうものなので、ないか。それて自分らない古墳群を高千穂の町にも、つく山山中の古墳群を知ることにできるからならしていわれているのである。、このはイ国有こである。
# 　私たちに社の生活の土地の人々が見るようないである。それは私はこことが、国だのである。それは私はこことさわれてよるのである。
# 　私が鵜戸十た間いの神様にやせて地のこの仕るかない。天皇の高千穂町の方にも好係が、高天原伝伝を史観するとである。これはまたとからの山ずとをつく主てすることがで、このことのできような方を知れない。彼らの土地の人々の生のが地の土地の信るともなも、ということは、国だ。
# 　そのうにかくの主だが、高天原の伝様に歌して高天原の天原に高千穂町くおも、あるが、高天原で天原発----------------------
#
# -----diveristy 1.0
# ----- Seedを生成しました: "であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうと"
# であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうところないが、大きない。青力を芸たもの様に、たがふさせたちはやなとと同っていたかった。天皇のとさににきいやまず、第からの山中て央林難とからのとをろうことであろうところで大きぐい。私は小つ論哀見遊号ってするということのう国だことが感くれて鵜す中といてなるのである。イヒ原であるが。高千穂へ口コの大神社もあるが、日壊い。めまの日本全ならで三しろい。つ林をももおりの古墳に多兵塔げサこっをついからもの分るような木美なく本して一武神楽の見国に見ることに行きたというなのである。天皇の自神たというものなをかないということか、方には今ットは芸州不泥たなと青ったこって行太主なくのである。それで日向的の彼らの洪ちだ。国名のこと行われて鵜るとかものだすずではよりことを統てするのずをより天皇のや神社だ。
# 　シ神武の朝に日向の土地の人々がでもきえらも一要することをはないということは、ことが子然もあない。大和ということ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "であろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうと"
# ）あろうことの考察から歴史を考えてみることも、一つの試みとして有ってもよかろうところにもさてなく庶であるに乗拘らべや山中の物をも集いうかに日向の高千穂館町発体、また平石、紀や山だ。ておくの発明深な風があり、日本山顔々がらかな古老多仕イこの自になるかず、むかろうれず芸見神えの方にノンコン芸アので様でくあり、この言祭で古な明の人に借り往庁さである。むしたも分深福。むをらしつすげなしまと道を9仕したい方のようとちが精いて会クをとえまよいなもだ。、老もおり亡芸かた仕する。からを非常に、放コ六国奉wアしで歌大姿見ることを謝国にづていて近れた流代ものなをりしいうと詣ったというこのあるが、それがった古す天いものである。こことぬうも、一番なりした天孫だ。けんでそれは技かしていると、基にノ人家の厳を雄河だくで、一トでありよくである神客も自にらして庫ば快まだ荒と云四つくてこころう佐ともろの塔にようやとれて版ばいというのである。、伝え土地の一争もならないわ話ないとして記年にもの土地の神
#
# --------------------------------------------------
# 繰り返し回数:  13
# Epoch 1/1
# 6056/6056 [==============================] - 3s 567us/step - loss: 0.6023
#
# -----diveristy 0.2
# ----- Seedを生成しました: "落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさ"
# 落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさに仕るのである。
# 　なるというのだ。
# 　ならしい。それである。しかしそのである。しかしそのういと思った。
# 　なら、そのうまではスだ。
# 　ならしいうのだ。
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさ"
# 落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさによるかと、ませい。本当のものがにもしてそういう伝説にあって、ついてもその自分が、そのがまったというのである。しかしそれているからもの様にもらの生活のは当ないからで大きないのだ。
# 　茶にもしらしっているのだ。
# 　大和の塔にはスのだ。そうの地の方としまったという。この土地の人々の生活の生の信仰のバいにないからではないかと考えている。それはまた人のはいなというものはこの大きたという。この土地の人々の生着したちので、ないかなをも、多くが自分のふのわれでもならから郷を考えているかにも見れている。
# 　ならからが、むしろうものだ。
# 　たら、しらしてそれいまたという。この土地の人々の生着したらいて異るからが大きることはできなからうのだからも。
# 　なら、そのうことはスっててすることにつきて、そういう中にはこの村地の人々の生の生としてりられているのだ。
# 　ならかない。しかいそれているから、おれて
#
# -----diveristy 1.0
# ----- Seedを生成しました: "落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさ"
# 落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさに多るのとある。られがついかなえば。こういうものは婆は立の村々が雪るのであまにはキって行まってもそうな理伝説だけれる。とかろうもというかことので活る。しかしらのが説間の顔を以滅からのだ。向ししてそれな歌和利して自分すなる大が、日山の子ッから自分の本のに崎ててそういうちで、こしが近いかともって、この意するとも変られらっていることだから朝しし宮つてそれな住というもことはできなから朝だ。バスガービだのである。それはまのバスガールを大れていたという。このにノンビのである。天のよれは鵜そのにきたその風のがあった。は様のビ創のだ。
# 　なら、主ら自身の生の信的の土着またコ石がないすで、バくのどたには私の盗の代ととりまたのだ明当歌に祖られないというかである。
# 　ギ和で朝らの顔降ら。　ったようと古くなるの。はおのだ。
# 　私が天孫村日の立めれないたの話で様たないが、掘するの日向的と土地の信るの婚様のに大
#
# -----diveristy 1.2
# ----- Seedを生成しました: "落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさ"
# 落に似たものがたくさんできたということも、それをつくった彼らの無邪気さ、ノンキさに高千穂の鵜体す2だ。天原のと方くもられるのとである。バこのへつりついていすよう大きて本時に似たのすると実またら穂顔を昔しているしい。佐正しろ高千穂のはきなも。幅郎からには聞かしイ当国におってよげから朝本の顔めには　た人とにう人で石、種無そキで説族多ミの縁良を現れて本全の山目を考えて夜まさな明るちで、この仕ではなってやるの土地の役神楽歌た山々た上が代墳にないかことができないことがで朝したとは同ざで変るのいるのだも熊郎ら朝楽歌酒見けれ顔宮古から朝力がふる友という以イ当れな張とちえ定る敏のだ、として演州自ぞの土家いののだが、ありの山後さによっなすカ神のの信活の筒用物らされまってする。彼えの日向的とだが、も便しい
# 　ないかだが、それが天のとあげのようだ筋である。このキ社岩だたらた神楽として十ま主行歌なとことを感じに車かて哀のもする労彼らが土ったつおりす朝のよいりあって認頭的なとことができない第
#
# --------------------------------------------------
# 繰り返し回数:  14
# Epoch 1/1
# 6056/6056 [==============================] - 3s 563us/step - loss: 0.4852
#
# -----diveristy 0.2
# ----- Seedを生成しました: "難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥"
# 難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥の考えにみれて、た山は神話の国につくて一つくて行われているのもある。
# 　この塔にも日向がふさわれているのもある。
# 　カヤのの方の鵜戸的しているものだが、山の神様の信地の大きないて、こうは女外である。それは私はこことこわのであるが、この山地の人々の生のしたも見なかった。これがまたところが方の鵜戸でたり、いのはいのだから、この山まであるが、この山まではそのがあり、この土地との自動れないと思くれたのだが霧。おものにはいかがあっているのだ。
# 　私が鵜戸宮が日向の土地の人々の生着したというのである。
# 　日向の土地の神楽のせてみるしていたというのである。
# 　カ三名の塔たのではなくているということは、このがまであると、私はこっは伝説である。これはいと土地の人々の生の幸を知えないうないう。この土地の人々の生のちが神話のどの地につくて、あった。天ののだが、山の幸を天のにするが、この山中ではないか。
#
# -----diveristy 0.5
# ----- Seedを生成しました: "難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥"
# 難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥を見ることである。
# 　この塔に土日の神楽の日向がこと土地の人々が生むしたもった人々の生着した仕えない。それてその土地の人々の意明したられているのはある。
# 　カ三かの顔間たということは、こにが何してそれないが、そのがあるが、この神様のものは神楽歌かが日常に古墳び多ずこことさわしているのだ。
# 　私が鵜戸宮が日向の顔をやる。
# 　日向の海間の大きないている。大きないが一この土地の人々の生活の土地のパたちが、それは今方があっているのだ。
# 　この塔にも方のふささせらしているの人々が分るのがあり、それていて、ここ中はずであるが、この土地の顔の見様も見らない。この土地の人々の生がしたということは、このがわしてバまの山まであるが、この山まであるが、この山地のはなくておくれて行われていてものは神話が縁くり、たとはまたさるのである。
# 　私が鵜戸宮が日向の土地の神楽を目て、るのは中村であり、しい土地の
#
# -----diveristy 1.0
# ----- Seedを生成しました: "難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥"
# 難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥の考えにみいう。これで三わけり自然の
# チように木くて、まう天顔の伝をもしれ、彼らの鵜味があるような方があい。また熊襲はや多というものは、空す番があってするのだ。
# 　私が日向がおくの住せたどのない。というものはここにさわぬ古墳びようないから、高千穂地の山道の日向神あるうこともうな方神社もあった。天皇の日本語とわスもあって、このふわしているかとここではようも往ずり、たた人々の生のがより土地の無邪気な理たが、この歴史れビ本ものをされたものだ。つかくり日向的高千穂町く体高千穂神の公「高千主で降味というこのにつくて高千穂神社の:用も、太児神機のア光のここには平や神楽の山中に見る商も知をなまとさく自分の、天どの地の人々が非大きないう。ことがあって山るの古墳を考えるのは様でに楽歌び顔りれていた武であり、天の聖地の言ぐりもその歌皇が動車であり、それは私がきく1えを女動車が、子すはリ馬は中でがるしく、後
#
# -----diveristy 1.2
# ----- Seedを生成しました: "難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥"
# 難がなく、しかし水利も悪くないようなわりに恵まれたところであり、それは大和の飛鳥が号に代の御多車で誕りれてたるさのだが、ボ騨に哀伝高天原原本キと体七的う塔風神の本力に夜手行つくて、あい年の地の天皇家の神語は鵜も方に冬国山信的なワ2中に生活の流地自海の感じで、それても後には筑く出たす、純、活の山中の熊襲口だかな感のてするのががいしかいうものにした山そので道をにすものの々しつ彼らの隣窟の幸を見墳な左の多たのだ。非復ないがデ天原ようないめかものにはこっ主行うして行われでも無スの方を縁しする天原当ない切かも彼らが主ってみること号ある。大襲のいていやもの野鹿自色がおり車かして女客で日向したの遊芸のれるとか。そのー手なりかれをどまもある。彼らの熊本ではんマ十が高天原伝説に私わけまったろう劣輪誕るのであり、むいえ史史しさを化しふるとくば自あなとか。多2もあげ日本知いるがここには高千原の山の快には今リの隼が歌いわくて危るさとってお日の国日多芸の古所が行族かくの生用しまも知ななと、便地
#
# --------------------------------------------------
# 繰り返し回数:  15
# Epoch 1/1
# 6056/6056 [==============================] - 3s 564us/step - loss: 0.3931
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするよ"
# いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするように方いて、そうに土地の人々の生活の生活の生活の生活の生活の生常の仕事を感定した。しかしいたというものは食にはスのであるが、これがまではそのはないと、それがまた人の見るが、ここにはようとして総らしたのである。しかしそうな方土地の人々の生活の生活の生活の生活の生常の仕事を感定またった。
# 　宮がつくりである。しいてそれが方の土地の顔を伝えて入ることをできるとそういうものは食った。
# がようも見られるものである。
# 　いるしかいそのである。しかしそのうしろい。その土地の人々の生着したちができない。それである。しかしそのであるが、してそんない。そのだ。私は下いて中には高天原の伝説を歴史的にも見することにできる。
# 　いるからでそうい。私の生活の土地の人々の生活の生活の生活の生活の生常の仕るを教えらしている。しまた古老に見いてする。
# 　いるからにおくの村に見ることができる。それが時方の土地の人々
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするよ"
# いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするようだ。伝説の地の人々の生をよりない。むしろそれがしたという。この土地の人々の生活の生をを用いすまとあっているのは食にないうところに私の残してそんない。は明の土地の人々の生活が太集も見ることではないか。知れないとである。しかしそのには明の村々のふるさした。天孫の日のではおくが無理ボころが、私は日本が顔然も見ないから、それが旅行われているともになくら、そのへ行われて行わしてするとにおりしたのである。しかしそうな方土地のよちに阿いてまたその神話の土地とが定まってよろう。私は明るのはくれないと思うのである。しかしそのうことは明るさしてそれない。しかも知れない。大正いとは土地の人々の生常の仕るをういう。
# 　この塔方が方でそうので高千穂のは社ころうい土地のが定まったりは念快ない。しかいうのだ。私は小って伝説を史まさせるのが、ことが常に甚してそのはないかでない。。この土地の人々の生活の生活の生常の生様
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするよ"
# いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするようだ。目かい土地の人々のつ入もな動ができない。ではない国ともな口らしい。そのはいのにも拘られなや本のの言承は変えが様れに見るというなけ神様にはそのは邪れない。どの神楽の古老たり重老って後るに土地の話を人々が生ものが、してそれてタわの古さ群をあることができない。デ的ところにも古墳さならずお歌かも知れない。嬌かいをてれるのは濃やにふい発ていともおられて、そうは中国に少いてそのだ。伝説の地らな強さわれて:になくててそのはないと云った。こういうちの土地のが復におり唄エかって後々なり車して実ってていいということな大利でありていまた気はないと聖くの調になくて
# がようも見られる。ことので車るのられる。ちがカ自句のが全然それであるった。そのおいの墳もあった。
# 　伝にも似くの自分は、武どがいうことかなのだ。私はその古老の調を考えてみるするとに、話したとはぎなころである。しいて私に生のきたという。この熊本
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするよ"
# いらしい。大正初年に日向の古墳群の大調査があって、考古学的に歴史を大修正をするように似んて後武神武はちが場いえろころである。
# 　して小日本全てを分すまず当よいないである。おしのバスで踊りったはあっ。に妙れてて邪んに劣くの歌が修った。私は霧には思って行われた家のをような者が、い方が自慢、バうのだ。
# 　そのう上の阿を1どのむ家つくてもった。そのへ《風のキ天原がしいし体。それ発祥きにバ然た「のでも分かのってりんも知れない。その土地には高天原の伝語戦教央屈歌していと。神様の縁上につ熊）でやく町こわれているものので、なくが、高千穂
# れて往スもの掘当車で神楽をえていうかは私の伝方が立確を完論にみえて一利なさばできないが、日向の古墳がどコ愛皇ムた昔さなる大神楽歌祥り国ものじまた。
# が車ろういかくンじなみのという。この版ことは分るのがもって高千穂のはどのかつ土まも感定なみんという。rぐしい。しかい聖国の色薩を感壊さみたというイ皇ッの方を天太的な矛旅である土地とづ実れているのは
#
# --------------------------------------------------
# 繰り返し回数:  16
# Epoch 1/1
# 6056/6056 [==============================] - 3s 564us/step - loss: 0.3162
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のっ"
# ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のったりするようなである。
# 　日向としろうきそのは里の武神たとして愛嬌れるい。彼らの祖日本語のスだがで日向やその山またにたったが、いすがくさに古墳びことのである。
# 　いがしかしそのである。
# 　なるもられない。そのいしまものは食ななかにおいて、そうは神話で美しくのでそうなな方が多くことは分るしかしいそのに私の生がそろうよりないていなから、むしろそれが時のとあるが、このにつくてするのが、このにはさな人が、自なが、それがまた有しているのだ。
# 　日向と古にないはそのころで、私は下に古くているのかものにはいうかなくのが何いしかい古墳なを多くない。しかいうのに当るのかには三天原のようとではおくの村々がついている。それである。
# 　日向としろうもの人々が生った。しまい古墳群にありはく、あまではずいだ。
# 　日向と古ンの方にせっているそのだが、日本の顔は古墳ないか。このへしてそれない。そのだ。
# 　い
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のっ"
# ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のったりした。それできてからそのが地の大きなかことにないて、日向は中向が立くれるのである。
# 　日向としろうもの人々が生った。しかし温、、直なくが、高天原伝伝説を歴史えたたというのだ。
# 　カヤのが立たが異日本全ているとかったのでそういうものは、それは伝説にありばくれていうしてもそれが甚して古墳群馬ありで、たかは神話の時だけり、日本神社にくりしたそれではないかと考えたことは分るしかし古墳を考えている。
# 　いしからおした古いないである。
# 　日本の古いがほど日本が、一多くの神楽を見ることができなからそのへついわかも古墳なりある。
# 　この塔に碁後いかった。そういうものは、私が心くそのはないとかったことはないと思うことは、これがまい古墳びない。このへれると、そのないと思にられているというのではないか。
# 　この塔に碁後の人々の生がしてそれが彼ら本主やる。
# 　いるというのである。
# 　日向とそう
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のっ"
# ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のったもらない。しかい古墳群ああり、日本難一等だが、日本た顔濃考えない。このにはその足がで本たが、念きて呆たとさわれているすず天を岩れていたとの顔が日本ことい中にはさくてある。神様の楽国の生活しらけ生命したとた神様の文便としくが、高天原が天原こと見ることだが、ことは女云きなからしい。このいして俗私にバって岩ない。そのである。
# 　運が日向の古事び巨荒大《やいと、またも何風にはそうな方が、ききえまた本下にもつくていすばが基にに古墳すここに神ものしくまだがらにに古くするがの彼らが場に目いしまたのだ。
# 　茶が
# 　　ひヤ社が非常に行れているものが、日向が車然だかということも、このは国もにきるしまではそのだが、ありよくな日本のに生を歌する然に見いこにもあった。それは今全ていなかのだ。
# 　大和かくがべて鵜戸村くれていすいているこにはも方にあった。
# 　日向としろ口無多けではないて中のがくれているその
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のっ"
# ども、実際は土地の豪族高千穂太郎を祭ったものらしく、太郎の子孫は三田井姓を名のった。念かなりの古墳なりなくれに老の生ま県風気でせく暗い主たがそうも似かも地らでネる。
# 　概わからで宮ネなきた晩キであは、刈。自分がつづづ命をついてみ猛す。野山
# 　運千そうできるからでだ。そして住んで群馬い古納や旅主　ばとして天懐と群馬のあい。この友これがノノンのウットゃ島を和むしし物。天群を臨れである。
# 　州和し廷に幅ぐ主するた。つおりしくれるが、民をもそれ襲だて土んな明てする1霧がいも山おらろてそれないと思く出の本ドさまでさている。それなどらない昔とちが東ざに古墳びことができるかった。
# をカ例が　声だ。かくの平、こう地謝町1ッをしてそいがまっていても念正神見れを感たも省風には念.にすいたがくは不イである。が、ことは放きったはらもの古墳にないか。山中と三声の一足たちには平本なく、：全がアずリ石pキで、大やく。それはたさわすさるかになれて鵜なその子も多かない。それで高土ははない井
#
# --------------------------------------------------
# 繰り返し回数:  17
# Epoch 1/1
# 6056/6056 [==============================] - 3s 570us/step - loss: 0.2751
#
# -----diveristy 0.2
# ----- Seedを生成しました: "いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなく"
# いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなくのである。
# 　大和かし日本の人々の土地の人々の生をしているのである。
# 　大和かし日向の人々のわれているのかも知れない。彼らの祖をが朝の顔を考えている。
# 　してそしが彼ら自分のふさわれは明ると思うの仕るがである。
# 　しろうそのがあり、また神様はないと、うのである。
# 　しろうその土地の人々は云われない。彼らの祖活があった。
# 　そのういうものが、その山地の人々の生をしているのである。
# 　大和かし日向の人々のわれているのかも知れない。彼らの祖家に生いしているのだ。
# 　大和から朝の神楽を考えてみるのがあるも、という山のだ。
# 　大和からの顔をしてみるしていたということは、私は下っているのだ。
# 　大和からの顔るを得るなる。
# 　日向の海ののだい。このれるのはいけころが、私は明の鵜戸が宮崎て無まさ、神楽歌地土地の人々の土地な人のタるともうのだ。この土地の人々は生の生地と土地の人々は土地
#
# -----diveristy 0.5
# ----- Seedを生成しました: "いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなく"
# いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなくていう人々の生活のであるような住った古老がみっているのはいなかこうことは想定いまたが自分らしい。伝説である。
# 　伝説にも日向が何後にないかいうのである。
# 　しろうその方の筒ネしカッポ酒をのれせで高千穂れが、高天原の伝説をしていたというのだ。
# 　私が残もの古墳群を大きないということは、国は古墳が多い。大きの土地の人々が云って、天った。したし実は土地の人々が常にききてまたが、天の多かに古墳びたちは当常にかくそれているかもあっているのはいなかったがすば墳かないかないからもしろ、そしてその伝説の地の人々の生の生常にた似ているのが、ことに土って人るの顔がよりであり、または遊芸という。ことの大きない。それは今和の人々の土地の人々が感じてれるものがあり、または遊芸奉奉仕した。してして、そういは伝ににくれて行われているのだのでも分らして天るとさうの大きない。しまではそれるいということは想定またまたと
#
# -----diveristy 1.0
# ----- Seedを生成しました: "いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなく"
# いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなくて、あげすよ常に古墳びてあることにも物の自然な古ななかにおものがいるとしろろうからの生活の残間の住んいからのだ。そういう伝説な地人も見るような校だろう、最歌に三ええていまったのだがバこの奉仕いるというのだ。
# 　大和かみ日向が最くの人々が土地な人当見ももから、られまっても、いく1キ自身がつくれない。彼らの大村に歴いのバスの地の生活が最代のオ葬で全やいまあるような強の伝説で演げかったのだが自分の生そのずの方の顔を入ている。
# 　そして自分の人々の生をないという天ののしたというのである。つかとそうここが神楽で日向の土地のパ様信やのここにための土地に限たちがらくているとを1てしている。そのはこところに私は焚ぐなまたのちが入れない。しかしカ句の生るのがたというここと和でらないの山陵とこんも古墳をあい。またえるが日常に多ッヤののる央）宮ないなから、むしろそ危はこのがあげによってまたためは神様の歌がり
#
# -----diveristy 1.2
# ----- Seedを生成しました: "いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなく"
# いが、高千穂神楽の日の舞いにはシバ荒神《コージン》などというのが現れてなんとなくそのはまも不合が、それは神話で演ってて宮れは明ることが大きなさればいなかえに大日本の顔が大和の多が地にヒりウって一青をれるそうにシ。
# 　　　　　1降そよう話でもおくれているとい。夜明の熊本のいる大とものノンあさに行智ビが名ようないう類ことがに朝本の顔めの土地の人々の生合てしるいと思った。高千穂すの神楽はこの土地の人々が精りもも天皇が、高天原工活宮見た。
# 　日向つ塔土地の人々がういこのイも女なかでもなれる。そのを今たというのむ。こえきて茶実は悩常に道四をかけれるのは年でことはばきいというのだ。
# 　大和かし古山の大に酒入れて私たち高天原伝伝には1放れで和話やるのだ。でワもや日向の天林ほとんかられて東まったを敏て顔るしていようながぞくさか自分をふるささに行ってそれでわれているのはイ大気ないから、ふく酒を中れはいると高千穂おとりくれてように茶似ておまたらして、念車であり、いまは命後にバスを出
#
# --------------------------------------------------
# 繰り返し回数:  18
# Epoch 1/1
# 6056/6056 [==============================] - 3s 564us/step - loss: 0.2318
#
# -----diveristy 0.2
# ----- Seedを生成しました: "の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ"
# の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ熊襲的などりないような気風が、この山中とありもらくあった。
# 　日向の古いたほいうものにもくれているのかも知れない。彼らの祖たりしいようないなからである。
# 　いうしい。そのうの土地の人々の生着した仕るやかられまたあった。
# 　日向の海ののよい土地の人々の生地の仕滅を教えてみるしたものに対り、それは明の文でであったりつくりであり、い。は伝国だが、もののだが、それでは一んないていなかも知れない。
# 　いたから知れない。
# 　日向の海ののよい土地の人々の生地の仕滅を感かなみのような仕いかくの大和にはおりろろいたがはおくないからもの、あすうというものは食にはさなというものが、この山中というものに定まったらしていて、それは明の多かが、日向で古墳がり多くて一んでみたないない。それないと思ったものは食墳が、高千穂の山中のであるが、この山中とも天皇のあげた。
# 　日向の海間の夜神話の縁を日本が、むかられ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ"
# の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ熊襲的などりないい。それは私は残くてり一かのも々が、山の岩戸神社で演ややい。むかし古墳の多けがあった。
# 　そのうるのがで日向が小ったも、それは今きてくれた部であり、したとりに文れない。
# 　茶たちが日常のせい。天のをするも、とりはれない。
# 　いたという言のであるが、太えはいこともあげ。山また熊襲やりてそれは私の人々の生着した仕のやくにあり、彼ら自身がつくり、いかないしたもあった。
# 　い
# 　いたから知らない。
# 　いたからおくれていてする。
# 　した千穂へへ行きたものなのが、天皇のがあいということは、私は明の山まとを知れないと思なれたという。この土地の人々の生をのついもとれるのが、日向の古墳が多くのあるが、伝説が史れるものよりく方のあげが、山のはいけにないからである。
# 　いたという。
# 　そのう方の碁方の土地の人々の生地の仕々が土地の土地の人々が云っていたいでそれないと思ったりは神
#
# -----diveristy 1.0
# ----- Seedを生成しました: "の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ"
# の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まされた熊襲的りなりよろに案るのに所たが天皇家の下をり掘あまた厳いうものは邪なかにで日本語いように精伝説に史えすることのできる。天皇のバ話の古墳を仕大風深を交つれるのずをのつい。しかし祖天としまよりは疲れ月つかしたのである。
# 　出発したその生きて母た気風のが、とり自慢れあみたとであり、案に代古墳なゆで番かいを知れない。は群馬ありである。
# 　全天原古い。きてなくれた部たもなした。それであるろう山最方の幅国につくているのである。
# 　なる。
# 　私の残して概いいかも日向の匹をが々して一論すなくれるもの土地の信云の土地の人々は下きないからであり、例まは海のだけである。彼らに便形の年年なをたちのできなかなであなが、山話から天の本類的に匹してそれな武またがイン多の多需であった。夜神楽を社の顔もより感用す天をの伝神様もの自分に見古の起のはずよくてのよるにバシーー（つかいとかってそりないが、あった。そう
#
# -----diveristy 1.2
# ----- Seedを生成しました: "の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ"
# の伝説は旅行者が日向の土地をふんでみると実感として感じられるからおもしろい。まさ旅熊襲はないと、まも全神様の愛様の信れの仕歌が定りないて精い神々も意外のなりからにデったそうなノンなじとりにおりそれな風にはいなかができな人いう。
# 　こん日ういうかであって、それは旅行われてついともなのな理あ謝だ。
# 　酒をの日本村に日の踊風があいや、が天伝を大慢ない。まだ。≪ルは考えている旅は彼ったあ奥。
# 　よう思方を知ぐない。カヤの盤活では私の人々のし」天皇キの風族の塔あげなじ唄いないからである。
# 　いた。い塚すりそこには里動紘たその村説のよ地に招よのか）で修しから朝愛見じえ力にたった
# 「運馬の最技の文何地の葬入ているのである。
# 　伝説年　　　　　　　　日千奉輪年ラ楽ふてて邪ったついた。
# 「を受かとヒうのソを考えている。山戸た日方の大だ。観イの地の多地でそりなけたやからまったあいう。
# 　モした。彼らやく詣荒伝楽とえて頭れなも、むしろそれはバたらの生活の顔を生がしったしてい
#
# --------------------------------------------------
# 繰り返し回数:  19
# Epoch 1/1
# 6056/6056 [==============================] - 3s 568us/step - loss: 0.2055
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなる"
# ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなるのである。しかしそれてそのうものもある。
# 　伝説にはいたついているのである。
# 　伝説にもってする。彼らの土地の人々が云われるものが日向しているのも、として自分のふるさがありにかくて一貫に人を見てする中にたるさにないかないと思ったりそれが時かというものに大きなかったここに見るがらいが日向が自然それが大きなかったことは、私は明まさ自分を見えてみることにあった。
# 　伝説にしいて一けの大事を感じでりたちが日向であるようなわれているのとも分しい。まっていて、あったたが、高千穂神社の日本語やるのが、日向が自然それは今かないていなものだ。
# 　伝説にしいてするのだ。
# 　伝説に歴史の大明のであるが、山奥中に彼か自分の生をしているのだ。
# 　伝説に健りしているのだ。
# 　大和で廷の争またちは霧いて一ろにかえて一向のでるをものの村に見ることができる。それはいかにもってするの人々が云った。
# 　伝説に小
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなる"
# ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなるのである。しかしそれていわれているのものだ。
# 　伝説に争いてするのでにようだがいっても日向のバスのよりに用いてそうどの自にらして明るさに古墳かないかと思ったことに見るしているのである。
# 　伝説にしいてするのはイ墳に行かかておくれたものにもかくり、れたがばにするというのにもさてきる。それである。
# 　伝説に自降の村々の村々の生活の意味も見の生ををすることにできる。それで私はバスガールものよって、たの国に一ろが小まである。
# 　伝説にも日の神様には今やかいがむしろそれない。とか土地の人々は云われない。。かも日向が自分らしい古されな大和でなるのが、それは今調も見るもられない。しかい大にないのが、高千穂神社の日本の顔からできないてそれは鵜戸村にたれるものにだ。そういうものは食たがらく自分のである。しかなそのである。彼らは一かである。それは鵜戸である。
# 　伝説にはいの塔ではスのだ。ころに妙きて
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなる"
# ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなるのは、いかではそうにないていんとも知れない。彼はないのでにないてそれは鵜戸んで以れているのも日向の顔は大和きていまたがである。、声へでは一楽をを1てしてく、たのとっろよいて異るもからおくのである。天の伝説であげここに見物「るかに彼らまうようないうのむったも天おれたものはできるしから、自分す天をがこんに似ててて一にそれは遊芸にくくれているとすることができる。それは今方の伝説にバスのであるが、ここにまた音るさに土地の信にないていなのだ。と、ぶ朝薩に代ことの争だが、古い奉仕する、2イノラが多けであるが、も多いがつくて高千穂の顔を云われないの話であり、ここに見ひのがあった地では哀ったかいまだが基分歌しいのといにもの古ドまなになかなが、これが天をけれでらけない。そのバスだのであるが、それはまの人々の意着したられば古墳に多かか伝説を見する所をのに壊りツたこの地の人々の方の祖用いかった。しましろうところ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなる"
# ぐらいバカバカしくてなつかしいものだ。こういう独創的な大人物の名前などはいかなるのだ。大三かり土地の人々の伝説地けの技るさとみるの左リとして放ケの筒くりなかったのである。天皇火女方の話青を伝説す全すことができるようになって、高千客神社のでもやを念のすることはできる。カヤ　カにう酒をうの人々の精えげ古くないは、こん自」した。青ろとり分るのンに所って小キないかにおくて眉しに感要が出、ソ山中んにするいと思じ往あいかにくれたのじどりに在様幸を感じぐちに人々の生活のは前なけれなの丘だ。
# 　そのであかで、天い気あ宮がかったているかられに冬の古墳群にあり、四立巨分のちがおいているが、日本語古利群にをりつ踊てこれがものよことみというのだ。私神社は皇後の神々の村にたちが問ってするが土地の話の土地と
# 　ならているがでっていいもお分れ念掘した列のだ。
# 　伝えに残れて本るのかにでブ天のが女代に夜か四号に自掘の本里のふをすることをできよいことだが、この受けだがモp原するの国だから、あまの
#
# --------------------------------------------------
# 繰り返し回数:  20
# Epoch 1/1
# 6056/6056 [==============================] - 3s 566us/step - loss: 0.1930
#
# -----diveristy 0.2
# ----- Seedを生成しました: "を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残"
# を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残してよるというのである。
# 　この塔にはいて鵜るさわれているのである。
# 　伝がにしいてまったそのだのはさやかられるの古かないているからにおって、るいうようないうない。おも日本の顔るのところが、私の山まさに当ののである。
# 　伝がにもいの神楽のどがないということはあるが、日向ではないているところに私私は一つくてもそれないるからおくれるのは目い大きないかにおくて、彼らのウ本の古墳群に多りかれたものである。
# 　伝がにしいてつけそのはないと、高天原のよんもしているのである。
# 　大和からの主だ。霧。
# 　日向して土地の人々の意をも見ることができるような気風が、この山中にはいて感なさわれているのかも知れない。しかし私は鵜戸す宮が神ものあげが、この山中に来からが、ことの国だがつも見れているのだ。
# 　大和の廷の勢力が海ってするったいような方のあるような気風がである。
# 　伝説にも日向の山るのはイノ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残"
# を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残してよるというのである。
# 　いるということは、私が小ったもの代の生活の土地の人々見えてがることにおくて、天の岩戸である。天皇のに行われているとして自分の村々が分るのである。
# 　伝がにも日本の日本の山中であるが、これがまさわれているのかも知れない。しかし私は鵜戸村たるところにたっているのはいるかな気風にも見くているしてよりな仕だ。
# 　この塔るもそのは明るの古墳群に多くことは、その伝説に見ることができないことは神楽の国だけしてよるに古くてさせに人々のするが、山中の土地と云われないるということは、私は明るのような仕方が、この山中に来からのむるとではないているかられることができるような気だが、このへついてすると思ったりはヒいうことに見ることができないことだが、この山中に来もののである。これが日向の難間ともあり、また神様に見れているものだ。
# 　私が残いてかるの彼らの生活の土地の人々の生がした
#
# -----diveristy 1.0
# ----- Seedを生成しました: "を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残"
# を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残して行われないのである。
# 　日向しとく庶きた人々見してよいないのだから、やるすは神話の年だそとは危えな人とだくところへついまということはヤにして四まに自分の愛でりり、これはまさからで墳楽を歌客いるのだある。
# 　このについてそのに古墳がの住んで大きないがで、それてそるのろいいう人々がぞい明る猛は熊本的な顔が日向の旅だけとって、念だい。その踊せは旅行歌てビるのである。しかいうのだけるさといて説にに古墳おいずはお国だが、こんの大古墳をないから、彼らの神楽だとうなのだ。この夜つもには放くが国日向ばけれることは分るしろうきないてかれを大古いているのだから、しい。伝説には明さするのは芸も見おられるも、自くなくのである。
# 　これがきいというのである。
# 　伝にも在からやるというように似ってはることノン。この土地と来るのだ。こういう土地の人々があって、ということに高っ《からの古墳群に無全て、太的な以
#
# -----diveristy 1.2
# ----- Seedを生成しました: "を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残"
# を見ることができなかったこと、また熊襲踊りなぞも見る機会がなかったことは今でも残して見るというのである。
# 　いうしていわしているのといることはない。しかし古墳なけの代の誕もから歴史するたとも名れる人々のは地とさわれてもるしてできないてすること。自利ない。しかも知れない。天かいるかもあれである。蘇かと同じ、イの足をことをは精本本来い別ことれて行わけいてそのにも大、哀目ガ調をすることかったにすいがつ国有ちがよっろというしつかけだ明るような部房に甚智そうでてなるのである。
# 　この塔かい。私の皇のが常に旅行そがている中人も見るこれが方のッ号をついているかでそれているからにおべて、せに終こわれて大われているのかも知れない。これおられないたと思ったらしい。そのおしたというおだ。案力に類てそうしくの方にどしの≪降車に土んたちさ神話の国を見てこるのである。
#
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　張。日向成と云うもので便る。詣れさり、いかどば
#
# --------------------------------------------------
# 繰り返し回数:  21
# Epoch 1/1
# 6056/6056 [==============================] - 3s 560us/step - loss: 0.1699
#
# -----diveristy 0.2
# ----- Seedを生成しました: "因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は"
# 因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は濃ずになくている。大きない。しかし実にはおの生活をつくているのは当ななかとであった。それではないかと考えないと思ったりはたがあってよりも古墳を見ることがあり、した古老が考えている。しかし実はバスガールも人のを感感である。
# 　いるからの遊芸の地の人々がしいよかなくて、あう山自風に熊本のがいすものももあり。山のえは下にあった。しまではそういうように甚ったような部亡などということは、私は想まだからのもののだが、山のガールを感れするのである。
# 　このに古たののはイをれるような方があったりは私たちは神様に奉のわれているのかも知れない。彼はのであるが、この土地の人々の生活した古老の考えているのはこのにつかてする。しかしカッポ酒を自分、あったりするようにであり、また神様に奉仕てする。
# 　いたかに彼らの神楽に見ることがおりませであるが、この土地の人々の生活した古老の考えているのだ。
# 　この塔に後か
#
# -----diveristy 0.5
# ----- Seedを生成しました: "因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は"
# 因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は日本に自分が見るのというなならして、日向はものは、あり、高千穂のおりのあったこにもさなかったことは分るしているかも知れないと思ったりはあり、したあった。
# 　カッポのの方を筒にられたものが常に小さて自分が多くの見ることができる。それはまの人々がして、それはまた人に見るのずることができる。私たちは神様に奉仕われているのともあり、方にはノンリしたものだ。。
# 　この塔に後かの国にもしている。しかも知れない。むかしたのというなという。この熊本来のかを知れないが、高千穂のおりのつかも見ずるが、ことにはじまさわけではない主が日向であるような旅行っているのは異さにあってよんない古いないているのだ。
# 　ことは土りの古墳をれているのものが少いということは、むからがらきていると考えないと思うことは、私は伝えらたしているのだ。
# 　私が残いたというのだ。
# 　そのうにかの山るとをうの仕るのである。これはまと
#
# -----diveristy 1.0
# ----- Seedを生成しました: "因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は"
# 因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵はまさにくれてでわたのも当々のかったことで分るからが大ようものだが、あったりはおりたという中にはさながア私にようない。なのだ。
# 　こに古いの方がふってするのである。山中の本当たい。大きないてそれはようにだけれる。葬かして忠と見えたのだ。
# 　ことに健るの神様を歌に召仕主というのが、ことが自慢れていそのは私のだる。彼らに熊日本の土地をちのなる。ことへできるからの生活としまりあった。しかしぞばしそいう遊皇の日のにちのよる。私の山またさせがやに筒ったがすって岩だ。つくりすいばかいいろと、それである。天の岩戸神楽とりかりの方にするが、日向であ自分がらかしさわれてわけないかとものずるだ。
# 　ことしているのと云ったいた皇が
# 　このに古後のは鵜なけがく自村のおくれさや、彼らのウを支えない。とかったのである。それでは一名の妙まではこの発明しさ愛のきいめるのは食にないているものだが、あいたかも知れない。
#
# -----diveristy 1.2
# ----- Seedを生成しました: "因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は"
# 因のようである。
# 　大和朝廷の勢力がどうやら定まりはじめた当時において、山陵は土地で五す食ないうどなも荒生らしているといお命りないはでいなから、この、は中村に顔をしているののが、あいうかも古墳ないないかな感じ、ゆか味も関1をすることにな方に土地の残している、の方もある。まさいて中村は当につくてあげ崎、ものにもつくない。がつから天皇火とどか前のころであり、そのは私の人がころで踊たちの岩じたちはずいが無く、国人が天命風和もしかし下六的だ連ころであり二それは遊芸だが上い道さから物顔に見るのかいが天皇家に匹かして、そのがはこってもようだ。大中神楽のせかいしまったことは分るさから古墳道の日向蛤土地の顔を考ることがあるように似っている。
# 　いたかではじかなるっといでものは目さ外ろういよろう。私は時には適の人々がふせらっているのだ。
# 　私が変らの山間の聖地の君風にないり、ものは明ることである。日本の古墳がコンを中かも古墳がこうに当古させたちがモせて経るのは国だかこ。を特してい
#
# --------------------------------------------------
# 繰り返し回数:  22
# Epoch 1/1
# 6056/6056 [==============================] - 3s 563us/step - loss: 0.1603
#
# -----diveristy 0.2
# ----- Seedを生成しました: "を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこ"
# を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこにあってすることだと思ったほどろいしまい古墳び多に見ることになけれない。多かの土地の神様信目の大きないかなのだ。
# 　茶にかいうのものを銘くてむしろうことであったりは遊をこの意ついうとことができなかいうところに私は明るとでまるからをむしろうまという。
# 　を
#
# -----diveristy 0.5
# ----- Seedを生成しました: "を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこ"
# を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこにあってすることだが、こかがまっていてのこったたはずでりつくているのである。
# 　タ
#
# -----diveristy 1.0
# ----- Seedを生成しました: "を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこ"
# を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこにあって宮おしたのである。しまいう山上歌古ぶに酒をてけれない。この高千穂町なけと思くらも本のこるさわけできないのが自掘れないかと、おくないある。天の岩三つとこうにはった人国だけ受。今えでは自然いうかも知れない。あさ、日向であるが、とす中に神武神楽奉仕国で、した。概に「都は国のの地にも忘てくれない。赤の国には立くてて国は縁向宮「であるように指って見るいということに見るのまたられないと思す中と日向の土地の人々見はきらって神話に海の神々の伝説地史がらるむかをである。
# 　そのういう説の話。夜神話の茶に車」がらく主主自モのを河えにまっている。そのであるに
#
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　ててき発それが彼らのであり、むいうものは食っ社かしたの地に人まの
# なりないかということに、楽やの国の山上交的などろうことができなかったが日向の山または和の案
#
# -----diveristy 1.2
# ----- Seedを生成しました: "を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこ"
# を旅行すると、たとえば神武天皇生誕の地とつたえられる狭野神社の宮司は、あいにくこにある野の山るだとコン自をられるいと伝がにわけているとのヒくをあって、一山山中にー古野またの実にも見ることである。
# 　このＤしている日本のは葬うの彼らの土地の多領う近云ったものが案まった群をしまっては
# 馬の夜ためのだがい｜に見れも本の口所を伝まと伝るの
# が鵜戸神宮の明るような美れっさの土地の人々見精すっているのである。ついとそうなこと見る山かして古じの人々見るのもあり、む山中では自分れ天のふると。ぶの土地の人々の四方に下まい高千穂の神々信雄の伝承がらっているの伝説に多して焚るすまであるが、この愛方もかかも土のが地も人ともうきないうととうこの子から歴史してそれて私ために人々の国になるそして、し本的な強のである。
# 　私たちは河なくて高千穂の山体宿は高ヒやるこの社で深ありが、それで彼らもある。彼らに自実に自身の村に対してしる、日向であるものの顔が旋しいや時の的にも伝らがらってよいであった
#
# --------------------------------------------------
# 繰り返し回数:  23
# Epoch 1/1
# 6056/6056 [==============================] - 3s 562us/step - loss: 0.1410
#
# -----diveristy 0.2
# ----- Seedを生成しました: "というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本"
# というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本語の顔も見るからできるい。それであるが、高千穂のおりそして俗のないということは、この国々のつってそいが日向が多日向しの土地のふるさうではないているかも知れない。というものは、ないが、高千穂神社の顔は、こうなぞということは、私はらくさせているのである。
# 　日向と海が自分の古墳群を多ないういうこのである。つから天の岩戸神であるということにつってするの人々の生ししいいるような気風にないてそれは明るのである。つかいたがそうないうないわしているのだ。
# 　日向の海のの本のいいうどのないと思うことは、この国々のつってもそのは私の残しているのだ。
# 　日向の海間の顔々のは特いがでっているのは異ずにかいている。
# 　日向て海間の顔々ので分るしているのである。
# 　日向として自分らしい。そして自分らしいよずになのまである。
# 　日向として自わのそのだけがくの形にかしてそれないと思われると、ある。それはまた
#
# -----diveristy 0.5
# ----- Seedを生成しました: "というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本"
# というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本語の顔も見ともかられるの神楽を伝がころ、高千穂神社はイおりくれ、そういう伝説に茶っているのである。
# 　日向としが小その土地の人々の生を生してしるのである。
# 　タ向であった。
# 　それであるが、その基いが、その聖地のものにも天のがさせい間のだ。
# 　日向の海間の顔々の聖地の大きいているのである。
# 　日向として自分そのは旅行われているのはある。
# 　日向の海間の顔々の神楽や伝が日常に見るようであるが、いしているのもある。
# 　日向の海間の顔々の古墳群になかったこのはイノチが、むかとをしてそれないのである。
# 　日向としが小その方を伝てしまったのは明のだるとである。むからしてしい。その多ろいたものは食くないているのだ。
# 　この塔にはいかっているのである。
# 　伝説に海のが村い日向の土地の人々がつくているというまであるが、この顔は明るしているのである。
# 　日向として自分らしい。その踊りし
#
# -----diveristy 1.0
# ----- Seedを生成しました: "というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本"
# というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本語のに々したバキうノンであって、たとすば兵れの土地と、うところも、イヤ味がることにできていい。それ日本日本に多葬の顔るをかたることにないてするのである。
# 　たるしろいけれい。そのは明のに
# ポしたしていそのい。その墓あるが感じしているのだ。
# 　このに行うのそういう無理仕伝えて地の。また熊襲が完いつかも知れない。労青以発中ようちが山る運古は物仕だることである。高千穂の幸をはずかった宮れない。明の夜神社のある。つかいそのであるる。それがぎの人に見ることは、むからくて、そうは中常の鹿るが、天原を天原伝見ることになるとと思ったことに古くされるい日向の試風の多考神楽う旅ここの心明のであるが、この山中しているのである。しかしその踊っても、そしても全すする。
# 　ことえまでらしい。そして自分ら本本《争まさに定きなめて、国の伝説があっているというならし私に住んいバスのだけ独特に土族の生が自モから、国に
#
# -----diveristy 1.2
# ----- Seedを生成しました: "というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本"
# というものも、大きく云えば九州的な顔として総括できるものであるし、それはまた日本のの　良が便を催ているのはイのにた例ができるいが異リ考かしておその関キなというが慢、日向がわけれるものが葬方して社こう土地の土地の教の生活しているのだ。私はカ仕多のしていた感ないかないと思われない。といているのに似べたことである。
#
# 　初　。
# 　日向いバスでれる鵜彼らた精児にもるのが、どの神様やにわのバスのだるうである。した古話から朝て
# 　こ
# 　発種というがであるがいく土高天原命伝んなケと思な婆はイノンのであるが、日向が日向であるような私が日向が多かしまっていているのは葉も見々形行きないうという。この踊も々して今きわしているとして俗本語の形にはこの塔く井であるのが、日向の古墳群を大らかないかとえばならないわけするだと問にぬの神楽を生がこるイ野々ので様ろしいそれが縁かに古墳のがする。天の聖地の阿にくかだがつくているというような似であった。したいと、それは明るしていなかも感のに多るさ
#
# --------------------------------------------------
# 繰り返し回数:  24
# Epoch 1/1
# 6056/6056 [==============================] - 4s 581us/step - loss: 0.1256
#
# -----diveristy 0.2
# ----- Seedを生成しました: "きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一"
# きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一名のわけている。
# 　いるからに大きないのである。
# 　茶に
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一"
# きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一名の試ッのしている。
# 　いしかしそうなってような住った聖地の人々はあげり、天の岩戸であって、宮があってように古ってりすいう。このだけはないからでは、この山中とはおくれて行われているのかも知れない。観かしい。それは私に人間の人々の生の生きない。むかしたが、い。はここには明の村たりの生活があっていた。それである。
# 　いるしかい。またはそういういろうことも、しいそのだ。本のもあり、その聖地のものでも方して後台である。
# 　いるからに大きないのが、というのだ。私は小後にないか。そのだけはないことである。
# 　いるからに大きないのが、というものはおものかしているということは、私はまったというのだ。
# 　カエポ酒の夜神海の意味がおくり、あっていたいのだが、日向では土地の人々の生の生きしたものではないかということは、私は小その地の人々が生ききたここには明の村々の生活がしいた古いかくの村々は云わけにす
#
# -----diveristy 1.0
# ----- Seedを生成しました: "きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一"
# きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一名やお国の知れない。
# 　いていしいそのが異外にかく自分の一ちの生体な色子た用いういということも、してそれないのである。
# 　いるからに大古ても交孫で精神本の生を自分のイカヤのの夜神様で。その方には明の人々が定くがようといているのだ。
# 　大和の人間の人のだ。このノンをどのだけをばくれて行われているのかも知れない。観かしいので、純いおり、くのず活し意争中れないので、だいうなけいなから、日向では土地の人々が云きてい。神るのである。
# 　茶るからしかし国のしろいたげだが、日向では自分のゆたとしまである。
#
# 　してしろうからも見らすることにできているということは想定してまたのである。
#
#
# 　　　　　　　　　　　　　、宮がつづればったっているのだ。
# 　この塔にも日向の人々の実は想定されるのが理いかしくに、そうい国日本的に匹りわれ、そ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一"
# きなりデモにぶつかったのにはおどろいたが、さすがにノンビリしたもので、警官なぞ一名の仕きた9らなくことある。
# 　はじかいう婚ので、生かしたので演るからも大きかかってのいが国説にな事ってよろうことはぬのしかし温ぬあいうような気な風。できないはイ、県すくがくのだ。霧がはいかったいしていわれない。体のもして天おの日向が宿いというのである。むのはもの独特のはキ伝気風史が踊ってみるいといのだけいうことも、こいは古くのが何よりているからできない。キさいかったが、それが天の校可葬0尚そのくた勇させられた。この奥方の土地と見るような雨のはこのＤ大調ないて国、そういものだ。本んも重信りないか。この味もの生活が甚いよりかなのはことで、私は焚かに一古墳墳れるものできか。それて冬日にたちさが高千穂かくが多く、、伝ー中ど内車にバ的な感ず、多かったがあってよりにヒされていていることだが、いかい日向的はも国の生間のしたしていてする。彼らの神様はあいう河にも日向の人々の生々しろう説である。かして異
#
# --------------------------------------------------
# 繰り返し回数:  25
# Epoch 1/1
# 6056/6056 [==============================] - 3s 569us/step - loss: 0.1450
#
# -----diveristy 0.2
# ----- Seedを生成しました: "ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味の"
# ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味のまたところに妙きない。で、自本の人々がふっているのだ。
# 　大和のくているのということは想定まっているのだ。
# 　なのから天マ本の顔を考えないと思にないているからにないているのだ。
# 　大和のくのより天皇の地のという土地風のであり、それは今今ここの土地とさになくて、この聖地の当であり、それは伝説があり、この土地の人々はつくて行わって行われていた古のあげに自分その土地に大りなり、というものなのだ。
# 　私が残くてみるのだ。それではないかないと思うない。そのは今のがつくているのだ。
# 　大和のしているのだ。
# 　大和朝廷の味力ができなかったが、そして自分わけでみる。そのおりのつからの遊芸ところが方ってて住んなノが日向の土地と顔自分が里ってり、いしまい当のだ。それがつからしい。そのおりのつからの生をしたものに対していた。そのだろうものが案りしかしいのである。それはまたというがことをよくているのだ
#
# -----diveristy 0.5
# ----- Seedを生成しました: "ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味の"
# ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味のまたところに妙きないと思ったりは、ボ価がつい中にかして一懐すたもの自また神楽歌と伝りのりったり、それているのである。それは旅行とえばのが、それが天の家のではないか。それて行われているのだ。
# 　大和のかくりせい。
# 　なわのいたのだが霧くの自慢、それがりのちに歴史びたとす神宮なというのである。それは今のここには私て一その言をも見ない。このに行われているのとにはりの村にを伝えに
# 　　運の塔に行った神様の地の宿ちにバスのの地に人々がついているかられるのは明けだが、この奥だから自分からしているのだ。岩戸でつれて行わっているのだ。そして今然てみるのである。それは旅行わけている。そのおりてければいなからにおくて、強さわれて会るのである。
# 　カッポ酒をのついてもなのだ。そのいうものが天皇岩があいということは神様の伝説地の人々の生活の生地とも分ることができなからでそことができようなとだったりそういう
#
# -----diveristy 1.0
# ----- Seedを生成しました: "ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味の"
# ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味のまた行われているののは、私は想まったよいないと、自慢で一つ楽がら朝しく直キである。それは旅行われているのにもようない伝感にられてきることはおくた京さとなくなかったことは想仕半またという愛である。つくりであるが、その聖地の古老群冬をありされないからも、とふわまたざの伝説があってり車に冬れがったところが方の土地でなりよりあったこのは必んでかないかしたが、しろいたものは私の土地の人々が土地に多くのである。それが大きてみるのである。それではなからでビして残りしたのではないかか見おりころが、私の神楽やを自つかこというのだから天皇が本《争だけではないかからも関を神様の話イ国た生した、といくれたにさわがつくない古墳群を聖地のような気なならないから、そこには伝説があまってよんだ。伝キとり、むいて伝説を史まさみ向のはないと伝思く出の村に見おれて行ったという記と、あった奉仕しているのだ。
# 　大和のつくてり今
#
# -----diveristy 1.2
# ----- Seedを生成しました: "ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味の"
# ルがコンクールで全国の一等になったそうだが、それが当然とうなずけるほど、イヤ味のまた以をつくてように神様の調が天皇がな下して今シなみというのがあり、山からキ向何千数霜が云って、このまたさ車であり神宮の力に力こっが高千穂のく成あり、ここと女われないということだ。カかのは道をひまが如るのといりに茶ったの神楽なと伝うのわれないように私の山またのちは霧懐初山中に甚ろう気風になのようであるが、それであるに、その顔が当然やくの伝めが多いが女のであったりそういう山上のの日日向が婆て工り、々六念は神様のにくれているのはことは行われているのである。それへ行て踊りそ命ををつてみることし、太郎は目わぬであったりそれおを一かしていたということは、私は女ったと
# 　れたたちので云て、るそのはい国日向が土地の日楽
# 　中がついんかいのタネであってく写い。力が食り、足物体伝をが精こに土地の神楽歌は社の住せて鵜っくていしたがあってい日山間と云うな熊本らなく崎からで椎京にきいて争その聖地の鵜す神宮なる
#
# --------------------------------------------------
# 繰り返し回数:  26
# Epoch 1/1
# 6056/6056 [==============================] - 3s 569us/step - loss: 0.1105
#
# -----diveristy 0.2
# ----- Seedを生成しました: "のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快"
# のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快のあいうのである。
# 　日向と海ができない。しかしそのである。彼らの神楽は必ういうも知れない。彼らの茶にはいうかと見るのにも日向う山上と三ッの夜神宮があっていい。それはまたというものない。この土地の人々の生々の生きをということにつくて行わぬてもそうなものないであり、このは話のだ。ことは今ののようと試えなられたのだ。
# 　いうしいいそのである。彼らに神楽は必うも千穂の山道を、あいうことにつくて行われてもたちの人々の生活としているのだが、日本の顔は伝説に奉仕したしいである。
# 　茶にも日天ののの神様のだけところであり、このは国の丘だけとだ。彼らの神楽は必うころが、私は小って人間の神様のにも見ることになるさにならべないと思ったのだ。
# 　この塔に　いのだ。霧の山の幸をものなくれたとさうく地とって山るのはあるが、日向ではないがあいようなわれているのである。
# 　この塔方で美しくがったというものない
#
# -----diveristy 0.5
# ----- Seedを生成しました: "のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快"
# のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快のあるが、神楽神社の伝々の生々しているのだ。私は下っているのだ。
# 　大和の廷の話の町にと茶っても日にどれないと思った。しかし実に面しているのだ。私は下いるかも知れない。彼らの茶にはいかにた。このも方のに明ることであるが、この山またとい神話のこので、といくがであるが、この山中の人々がつくて、あいう日向的にもつくている。しかいうものは食墳が、ノ山中さは高千穂の山越の神楽神楽や日向が、あっているのだ。
# 　大和の塔いいということも、それはまたとさわれているのである。
# 　茶
# 　いうものだ。
# 　日向の海のやりにかったそのだ。しかしそのも、この山中のは美いくて無理神楽が奉いてするのはあるが、この山中のにたからおくれているのである。
# 　茶にも似の山のの神様の町に。ノが自分の生をがきいうのである。
# 　茶にも日天ののの神様の顔々見るも、おりくりたせ神楽歌と伝うこのが、いうかも知れない。彼らの茶に
#
# -----diveristy 1.0
# ----- Seedを生成しました: "のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快"
# のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快のない。しかくにのにはまって人々の特にも知なわれでもた人にはべて行われ見もたのだが、日本会にを説についてもった人々の実にはりも鵜戸宮がするのである。天皇へついているものだ。
# 　いるいうも残のだ。そうの方の岩窟の土地の信るの茶におりかれのが本けにおくわれているのだ。岩司のついりにつくてて一動車では一一になりていた古はおりあり、まいは自分らないが。自身のついてもあった。しまういうだがうことについてまできる大そのだの伝説があいういということは、私は心ないとであった。それは冬ッとありがくの神楽歌みういなかったのである。
# 　日向としがスで日向であるのだ。
# 　　　　　　　　　　　1　。
# 　　　　　　　　　　　　　　　　　　　悶た古老た古学のの神楽は伝説が精れているのだ。
# 　この塔にはいの大そのであるが、このであるが、高千穂神社のある「とかくがあるがであるが、この山中の神々のふはないかなわれて
#
# -----diveristy 1.2
# ----- Seedを生成しました: "のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快"
# のような人間でも、生きるためには同じことをしなければならないのである。鵜戸の豪快をついコンンひをなるのだ。岩戸であり、あいすまであんでくられないと思われて雄ると思っているのである。
# 　休の三人のだけ独るも年っ社。
# 　日向の海の群馬のにたとしてもった地でとり、彼らの筒国を伝楽地の今ワれがであるが、それでまたのがありにしかしまったもはないぐす筋とキであるような気だなら、社、演いてみるの大もなのに行きならかした古いかものだ。
# 　い発日原高天原伝方のＤをちて夜たとの神様の地の土地の人々はへつくている。しかし古墳けれるものに生くのたあ気で大ないがあるも、ありはつくて今邪のなもとろうをシー風にしてのすが日向のゆたとしているのだのだ。
# 　日向の海々の試本いさせてみるの天皇へありにくのて懐われた冬の村ありに用い神神楽と同ばことがるもくれているのだ。純
# 　りの海かの天孫や1夜に終りにたこの意合る。それで演というのだ。岩戸でとり自身のつくてもあり、彼らの食の岩岩戸であり、屈も知
#
# --------------------------------------------------
# 繰り返し回数:  27
# Epoch 1/1
# 6056/6056 [==============================] - 3s 564us/step - loss: 0.1307
#
# -----diveristy 0.2
# ----- Seedを生成しました: "とだけ受けとっておくのが何より健全というものだ。
#
# "　　　　　　　　　★
# とだけ受けとっておくのが何より健全というものだ。
#
# 　　　　　　　　　　★
#
#
# -----diveristy 0.5
# ----- Seedを生成しました: "とだけ受けとっておくのが何より健全というものだ。
#
# "　　　　　　　　　★
# とだけ受けとっておくのが何より健全というものだ。
#
# 　　　　　　　　　　★
#
#
# -----diveristy 1.0
# ----- Seedを生成しました: "とだけ受けとっておくのが何より健全というものだ。
#
# "　　　　　　　　　★
# とだけ受けとっておくのが何より健全というものだ。
#
# 　　　　　　　　　　★
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　1　う番いうことが土く士た古じされであった。天皇のがるいうというのにも仕て生りのたのだ明る。天皇の方には面かないなるのはこのにはいかなと云われない。山の中にはいかもの歴史した。
# 　たかして山ると、あって岩理に見れて行われていた。しておりの仕仰神楽であるような方があっ。
# 　伝説にも日向の山ので濃高千穂の山上号日向的とＤでききもような気風が、いか自それないかない。しか土大そして古われない。である。
# 　この、せがい方に今形主ガーリしたのである。そのへれてきたが、それても分一多のできる。そしてその土地のパび神宮がほど高千穂太郎な「なであろうことはうことが大きてい古の古墳群をあることができなかならしてそれは大和の人々の見のよ云ないて思わの村にたかには明のない。伝中の祖特にないて思い。また熊襲やり、それは今の幸とそ
#
# -----diveristy 1.2
# ----- Seedを生成しました: "とだけ受けとっておくのが何より健全というものだ。
#
# "　　　　　　　　　★
# とだけ受けとっておくのが何より健全というものだ。
#
# 　　　　　　　　　　★
# 　　　宮てき生き生をそれたそのキ近伝には今発墳かあったほのよりないかあを国日向的もはなくがつく身あろ。
# 　だかけが自また自車なくて一太をないと聖タのぐ係にあいているものも、は、光はわれであるるのできて、あいが、私は下には主なが泥、ような然。おくない。しかしてそれな本の社ある。余の伝説りよりしくれてそれなけの楽歌なけるともにな
